# %% [markdown]
# <a href="https://colab.research.google.com/github/ykitaguchi77/AdvancedPytorch_Colab/blob/master/Load_MNIST_sample.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

#dataset.zipを解凍
# !date -R
# !unzip -qq drive/My\ Drive/Deep_learning/examples-master.zip
# !date -R
# !ls
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Fri, 10 Apr 2020 07:17:13 +0000
# Fri, 10 Apr 2020 07:17:18 +0000
# drive  examples-master	sample_data

# %%
import os
#os.chdir('/content/examples-master')
#!ls
os.chdir('/content/examples-master/mnist')
# !ls
# Out:
# main.py  README.md  requirements.txt

# %%
# !python3 main.py
# Out:
# ...
# 9920512it [00:04, 2331658.69it/s]
# Extracting ../data/MNIST/raw/train-images-idx3-ubyte.gz to ../data/MNIST/raw
# ...
# 32768it [00:00, 121034.86it/s]
# Extracting ../data/MNIST/raw/train-labels-idx1-ubyte.gz to ../data/MNIST/raw
# ...
# 1654784it [00:00, 2387751.10it/s]
# Extracting ../data/MNIST/raw/t10k-images-idx3-ubyte.gz to ../data/MNIST/raw
# ...
# 8192it [00:00, 41888.94it/s]
# Extracting ../data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ../data/MNIST/raw
# Processing...
# Done!
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.333409
# Train Epoch: 1 [640/60000 (1%)]	Loss: 1.268057
# Train Epoch: 1 [1280/60000 (2%)]	Loss: 0.859086
# Train Epoch: 1 [1920/60000 (3%)]	Loss: 0.609263
# Train Epoch: 1 [2560/60000 (4%)]	Loss: 0.389231
# Train Epoch: 1 [3200/60000 (5%)]	Loss: 0.427538
# Train Epoch: 1 [3840/60000 (6%)]	Loss: 0.284316
# Train Epoch: 1 [4480/60000 (7%)]	Loss: 0.232256
# Train Epoch: 1 [5120/60000 (9%)]	Loss: 0.444866
# Train Epoch: 1 [5760/60000 (10%)]	Loss: 0.258934
# ...
