# %% [markdown]
# <a href="https://colab.research.google.com/github/ykitaguchi77/AdvancedPytorch_Colab/blob/master/5-1-2_DCGAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 第5章　GANによる画像生成
#
# - 準備

# %%
import os
import urllib.request
import zipfile
import tarfile

import matplotlib.pyplot as plt
# %matplotlib inline
from PIL import Image
import numpy as np

import sklearn
print(sklearn.__version__)

#Githubよりリポジトリをcloneする
# !git clone https://github.com/YutaroOgawa/pytorch_advanced.git
# Out:
# 0.22.2.post1
# Cloning into 'pytorch_advanced'...
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 445 (delta 0), reused 1 (delta 0), pack-reused 441
# Receiving objects: 100% (445/445), 14.63 MiB | 14.69 MiB/s, done.
# Resolving deltas: 100% (231/231), done.

# %% [markdown]
# #作業ディレクトリを移動

# %%
import os
path = '/content/pytorch_advanced/5_gan_generation'

#作業ディレクトリをpathに移動する
os.chdir(path)

#作業ディレクトリ直下のファイルを確認
# !ls
# Out:
# 5-1-2_DCGAN.ipynb  5-4_SAGAN.ipynb  make_folders_and_data_downloads.ipynb

# %%
# MNISTの手書き数字画像をダウンロードし読み込みます（2分ほど時間がかかります）
from sklearn.datasets import fetch_openml

mnist = fetch_openml('mnist_784', version=1, data_home="./data/")  
# data_homeは保存先を指定します

# %%
# データの取り出し
X = mnist.data
y = mnist.target

# MNISTのデータの1つ目を可視化する
plt.imshow(X[0].reshape(28, 28), cmap='gray')
print("この画像データのラベルは{}です".format(y[0]))

# フォルダ「data」の下にフォルダ「img_78」を作成する
data_dir_path = "./data/img_78/"
if not os.path.exists(data_dir_path):
    os.mkdir(data_dir_path)

# MNISTから数字7、8の画像だけフォルダ「img_78」に画像として保存していく
count7=0
count8=0
max_num=200  # 画像は200枚ずつ作成する

for i in range(len(X)):
    
    # 画像7の作成
    if (y[i] is "7") and (count7<max_num):
        file_path="./data/img_78/img_7_"+str(count7)+".jpg"
        im_f=(X[i].reshape(28, 28))  # 画像を28×28の形に変形
        pil_img_f = Image.fromarray(im_f.astype(np.uint8))  # 画像をPILに
        pil_img_f = pil_img_f.resize((64, 64), Image.BICUBIC)  # 64×64に拡大
        pil_img_f.save(file_path)  # 保存
        count7+=1 
    
    # 画像8の作成
    if (y[i] is "8") and (count8<max_num):
        file_path="./data/img_78/img_8_"+str(count8)+".jpg"
        im_f=(X[i].reshape(28, 28))  # 画像を28*28の形に変形
        pil_img_f = Image.fromarray(im_f.astype(np.uint8))  # 画像をPILに
        pil_img_f = pil_img_f.resize((64, 64), Image.BICUBIC)  # 64×64に拡大
        pil_img_f.save(file_path)  # 保存
        count8+=1
# Out:
# この画像データのラベルは5です

# %% [markdown]
# #ここから

# %%
import random
import math
import time
import pandas as pd
import numpy as np
from PIL import Image

import torch
import torch.utils.data as data
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from torchvision import transforms

# Setup seeds
torch.manual_seed(1234)
np.random.seed(1234)
random.seed(1234)

# %% [markdown]
# #**Generatorの実装**

# %%
class Generator(nn.Module):

    def __init__(self, z_dim=20, image_size=64):
        super(Generator, self).__init__()

        self.layer1 = nn.Sequential(
            nn.ConvTranspose2d(z_dim, image_size * 8,
                               kernel_size=4, stride=1),
            nn.BatchNorm2d(image_size * 8),
            nn.ReLU(inplace=True))

        self.layer2 = nn.Sequential(
            nn.ConvTranspose2d(image_size * 8, image_size * 4,
                               kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(image_size * 4),
            nn.ReLU(inplace=True))

        self.layer3 = nn.Sequential(
            nn.ConvTranspose2d(image_size * 4, image_size * 2,
                               kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(image_size * 2),
            nn.ReLU(inplace=True))

        self.layer4 = nn.Sequential(
            nn.ConvTranspose2d(image_size * 2, image_size,
                               kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(image_size),
            nn.ReLU(inplace=True))

        self.last = nn.Sequential(
            nn.ConvTranspose2d(image_size, 1, kernel_size=4,
                               stride=2, padding=1),
            nn.Tanh())
        # 注意：白黒画像なので出力チャネルは1つだけ

    def forward(self, z):
        out = self.layer1(z)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = self.last(out)

        return out

# %%
# 動作確認
import matplotlib.pyplot as plt
# %matplotlib inline

G = Generator(z_dim=20, image_size=64)

# 入力する乱数
input_z = torch.randn(1, 20)

# テンソルサイズを(1, 20, 1, 1)に変形
input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)

# 偽画像を出力
fake_images = G(input_z)

img_transformed = fake_images[0][0].detach().numpy()
plt.imshow(img_transformed, 'gray')
plt.show()

# %% [markdown]
# #**Discriminatorの実装**

# %%
class Discriminator(nn.Module):

    def __init__(self, z_dim=20, image_size=64):
        super(Discriminator, self).__init__()

        self.layer1 = nn.Sequential(
            nn.Conv2d(1, image_size, kernel_size=4,
                      stride=2, padding=1),
            nn.LeakyReLU(0.1, inplace=True))
        # 注意：白黒画像なので入力チャネルは1つだけ

        self.layer2 = nn.Sequential(
            nn.Conv2d(image_size, image_size*2, kernel_size=4,
                      stride=2, padding=1),
            nn.LeakyReLU(0.1, inplace=True))

        self.layer3 = nn.Sequential(
            nn.Conv2d(image_size*2, image_size*4, kernel_size=4,
                      stride=2, padding=1),
            nn.LeakyReLU(0.1, inplace=True))

        self.layer4 = nn.Sequential(
            nn.Conv2d(image_size*4, image_size*8, kernel_size=4,
                      stride=2, padding=1),
            nn.LeakyReLU(0.1, inplace=True))

        self.last = nn.Conv2d(image_size*8, 1, kernel_size=4, stride=1)

    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = self.last(out)

        return out

# %%
# 動作確認
D = Discriminator(z_dim=20, image_size=64)

# 偽画像を生成
input_z = torch.randn(1, 20)
input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
fake_images = G(input_z)

# 偽画像をDに入力
d_out = D(fake_images)

# 出力d_outにSigmoidをかけて0から1に変換
print(nn.Sigmoid()(d_out))
# Out:
# tensor([[[[0.5066]]]], grad_fn=<SigmoidBackward>)

# %% [markdown]
# #**GANの損失関数**

# %%
# Dの誤差関数のイメージ実装
# maximize log(D(x)) + log(1 - D(G(z)))


# ※ xが未定義なので動作はエラーになります
#---------------


# 正解ラベルを作成
mini_batch_size = 2
label_real = torch.full((mini_batch_size,), 1)

# 偽ラベルを作成
label_fake = torch.full((mini_batch_size,), 0)

# 誤差関数を定義
criterion = nn.BCEWithLogitsLoss(reduction='mean')

# 真の画像を判定
d_out_real = D(x)

# 偽の画像を生成して判定
input_z = torch.randn(mini_batch_size, 20)
input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
fake_images = G(input_z)
d_out_fake = D(fake_images)

# 誤差を計算
d_loss_real = criterion(d_out_real.view(-1), label_real)
d_loss_fake = criterion(d_out_fake.view(-1), label_fake)
d_loss = d_loss_real + d_loss_fake
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-b63842ae8769> in <module>()
#       9
#      10 # 真の画像を判定
# ---> 11 d_out_real = D(x)
#      12
#      13 # 偽の画像を生成して判定
#
# NameError: name 'x' is not defined

# %%
# Gの誤差関数のイメージ実装
# maximize log(D(G(z)))

# ※ xが未定義なので動作はエラーになります
#---------------


# 偽の画像を生成して判定
input_z = torch.randn(mini_batch_size, 20)
input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
fake_images = G(input_z)
d_out_fake = D(fake_images)

# 誤差を計算
g_loss = criterion(d_out_fake.view(-1), label_real)

# %% [markdown]
# #**DataLoaderの作成**

# %%
def make_datapath_list():
    """学習、検証の画像データとアノテーションデータへのファイルパスリストを作成する。 """

    train_img_list = list()  # 画像ファイルパスを格納

    for img_idx in range(200):
        img_path = "./data/img_78/img_7_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

        img_path = "./data/img_78/img_8_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

    return train_img_list

# %%
class ImageTransform():
    """画像の前処理クラス"""

    def __init__(self, mean, std):
        self.data_transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize(mean, std)
        ])

    def __call__(self, img):
        return self.data_transform(img)

# %%
class GAN_Img_Dataset(data.Dataset):
    """画像のDatasetクラス。PyTorchのDatasetクラスを継承"""

    def __init__(self, file_list, transform):
        self.file_list = file_list
        self.transform = transform

    def __len__(self):
        '''画像の枚数を返す'''
        return len(self.file_list)

    def __getitem__(self, index):
        '''前処理をした画像のTensor形式のデータを取得'''

        img_path = self.file_list[index]
        img = Image.open(img_path)  # [高さ][幅]白黒

        # 画像の前処理
        img_transformed = self.transform(img)

        return img_transformed

# %%
# DataLoaderの作成と動作確認

# ファイルリストを作成
train_img_list=make_datapath_list()

# Datasetを作成
mean = (0.5,)
std = (0.5,)
train_dataset = GAN_Img_Dataset(
    file_list=train_img_list, transform=ImageTransform(mean, std))

# DataLoaderを作成
batch_size = 64

train_dataloader = torch.utils.data.DataLoader(
    train_dataset, batch_size=batch_size, shuffle=True)

# 動作の確認
batch_iterator = iter(train_dataloader)  # イテレータに変換
imges = next(batch_iterator)  # 1番目の要素を取り出す
print(imges.size())  # torch.Size([64, 1, 64, 64])
# Out:
# torch.Size([64, 1, 64, 64])

# %% [markdown]
# #**学習させる**

# %%
# ネットワークの初期化
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        # Conv2dとConvTranspose2dの初期化
        nn.init.normal_(m.weight.data, 0.0, 0.02)
        nn.init.constant_(m.bias.data, 0)
    elif classname.find('BatchNorm') != -1:
        # BatchNorm2dの初期化
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)


# 初期化の実施
G.apply(weights_init)
D.apply(weights_init)

print("ネットワークの初期化完了")
# Out:
# ネットワークの初期化完了

# %%
# モデルを学習させる関数を作成


def train_model(G, D, dataloader, num_epochs):

    # GPUが使えるかを確認
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    print("使用デバイス：", device)

    # 最適化手法の設定
    g_lr, d_lr = 0.0001, 0.0004
    beta1, beta2 = 0.0, 0.9
    g_optimizer = torch.optim.Adam(G.parameters(), g_lr, [beta1, beta2])
    d_optimizer = torch.optim.Adam(D.parameters(), d_lr, [beta1, beta2])

    # 誤差関数を定義
    criterion = nn.BCEWithLogitsLoss(reduction='mean')

    # パラメータをハードコーディング
    z_dim = 20
    mini_batch_size = 64

    # ネットワークをGPUへ
    G.to(device)
    D.to(device)

    G.train()  # モデルを訓練モードに
    D.train()  # モデルを訓練モードに

    # ネットワークがある程度固定であれば、高速化させる
    torch.backends.cudnn.benchmark = True

    # 画像の枚数
    num_train_imgs = len(dataloader.dataset)
    batch_size = dataloader.batch_size

    # イテレーションカウンタをセット
    iteration = 1
    logs = []

    # epochのループ
    for epoch in range(num_epochs):

        # 開始時刻を保存
        t_epoch_start = time.time()
        epoch_g_loss = 0.0  # epochの損失和
        epoch_d_loss = 0.0  # epochの損失和

        print('-------------')
        print('Epoch {}/{}'.format(epoch, num_epochs))
        print('-------------')
        print('（train）')

        # データローダーからminibatchずつ取り出すループ
        for imges in dataloader:

            # --------------------
            # 1. Discriminatorの学習
            # --------------------
            # ミニバッチがサイズが1だと、バッチノーマライゼーションでエラーになるのでさける
            if imges.size()[0] == 1:
                continue

            # GPUが使えるならGPUにデータを送る
            imges = imges.to(device)

            # 正解ラベルと偽ラベルを作成
            # epochの最後のイテレーションはミニバッチの数が少なくなる
            mini_batch_size = imges.size()[0]
            label_real = torch.full((mini_batch_size,), 1).to(device)
            label_fake = torch.full((mini_batch_size,), 0).to(device)

            # 真の画像を判定
            d_out_real = D(imges)

            # 偽の画像を生成して判定
            input_z = torch.randn(mini_batch_size, z_dim).to(device)
            input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
            fake_images = G(input_z)
            d_out_fake = D(fake_images)

            # 誤差を計算
            d_loss_real = criterion(d_out_real.view(-1), label_real)
            d_loss_fake = criterion(d_out_fake.view(-1), label_fake)
            d_loss = d_loss_real + d_loss_fake

            # バックプロパゲーション
            g_optimizer.zero_grad()
            d_optimizer.zero_grad()

            d_loss.backward()
            d_optimizer.step()

            # --------------------
            # 2. Generatorの学習
            # --------------------
            # 偽の画像を生成して判定
            input_z = torch.randn(mini_batch_size, z_dim).to(device)
            input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
            fake_images = G(input_z)
            d_out_fake = D(fake_images)

            # 誤差を計算
            g_loss = criterion(d_out_fake.view(-1), label_real)

            # バックプロパゲーション
            g_optimizer.zero_grad()
            d_optimizer.zero_grad()
            g_loss.backward()
            g_optimizer.step()

            # --------------------
            # 3. 記録
            # --------------------
            epoch_d_loss += d_loss.item()
            epoch_g_loss += g_loss.item()
            iteration += 1

        # epochのphaseごとのlossと正解率
        t_epoch_finish = time.time()
        print('-------------')
        print('epoch {} || Epoch_D_Loss:{:.4f} ||Epoch_G_Loss:{:.4f}'.format(
            epoch, epoch_d_loss/batch_size, epoch_g_loss/batch_size))
        print('timer:  {:.4f} sec.'.format(t_epoch_finish - t_epoch_start))
        t_epoch_start = time.time()

    return G, D

# %%
# 学習・検証を実行する
# 6分ほどかかる
num_epochs = 100
G_update, D_update = train_model(
    G, D, dataloader=train_dataloader, num_epochs=num_epochs)
# Out:
# 使用デバイス： cuda:0
# -------------
# Epoch 0/500
# -------------
# （train）
# -------------
# epoch 0 || Epoch_D_Loss:0.0154 ||Epoch_G_Loss:0.7488
# timer:  0.4914 sec.
# -------------
# Epoch 1/500
# -------------
# （train）
# -------------
# epoch 1 || Epoch_D_Loss:0.0249 ||Epoch_G_Loss:0.5563
# timer:  0.4711 sec.
# -------------
# Epoch 2/500
# -------------
# （train）
# -------------
# epoch 2 || Epoch_D_Loss:0.0044 ||Epoch_G_Loss:0.6778
# timer:  0.4791 sec.
# -------------
# Epoch 3/500
# -------------
# （train）
# -------------
# epoch 3 || Epoch_D_Loss:0.0032 ||Epoch_G_Loss:0.7740
# timer:  0.4716 sec.
# -------------
# Epoch 4/500
# -------------
# （train）
# -------------
# epoch 4 || Epoch_D_Loss:0.0564 ||Epoch_G_Loss:0.5756
# timer:  0.4654 sec.
# -------------
# Epoch 5/500
# -------------
# （train）
# -------------
# epoch 5 || Epoch_D_Loss:0.0107 ||Epoch_G_Loss:0.6151
# timer:  0.4636 sec.
# -------------
# Epoch 6/500
# -------------
# （train）
# -------------
# epoch 6 || Epoch_D_Loss:0.0091 ||Epoch_G_Loss:0.6238
# timer:  0.4643 sec.
# -------------
# Epoch 7/500
# -------------
# （train）
# -------------
# epoch 7 || Epoch_D_Loss:0.0225 ||Epoch_G_Loss:0.6810
# timer:  0.4693 sec.
# -------------
# Epoch 8/500
# -------------
# （train）
# -------------
# epoch 8 || Epoch_D_Loss:0.0330 ||Epoch_G_Loss:0.4923
# timer:  0.4764 sec.
# -------------
# Epoch 9/500
# -------------
# （train）
# -------------
# epoch 9 || Epoch_D_Loss:0.0176 ||Epoch_G_Loss:0.5933
# timer:  0.4745 sec.
# -------------
# Epoch 10/500
# -------------
# （train）
# -------------
# epoch 10 || Epoch_D_Loss:0.0024 ||Epoch_G_Loss:0.7094
# timer:  0.4670 sec.
# -------------
# Epoch 11/500
# -------------
# （train）
# -------------
# epoch 11 || Epoch_D_Loss:0.0293 ||Epoch_G_Loss:0.6110
# timer:  0.4701 sec.
# -------------
# Epoch 12/500
# -------------
# （train）
# -------------
# epoch 12 || Epoch_D_Loss:0.0153 ||Epoch_G_Loss:0.7160
# timer:  0.4756 sec.
# -------------
# Epoch 13/500
# -------------
# （train）
# -------------
# epoch 13 || Epoch_D_Loss:0.0382 ||Epoch_G_Loss:0.4558
# timer:  0.4722 sec.
# -------------
# Epoch 14/500
# -------------
# （train）
# -------------
# epoch 14 || Epoch_D_Loss:0.0159 ||Epoch_G_Loss:0.6126
# timer:  0.4711 sec.
# -------------
# Epoch 15/500
# -------------
# （train）
# -------------
# epoch 15 || Epoch_D_Loss:0.0226 ||Epoch_G_Loss:0.6335
# timer:  0.4760 sec.
# -------------
# Epoch 16/500
# -------------
# （train）
# -------------
# epoch 16 || Epoch_D_Loss:0.0020 ||Epoch_G_Loss:0.7651
# timer:  0.4738 sec.
# -------------
# Epoch 17/500
# -------------
# （train）
# -------------
# epoch 17 || Epoch_D_Loss:0.0424 ||Epoch_G_Loss:0.6451
# timer:  0.4763 sec.
# -------------
# Epoch 18/500
# -------------
# （train）
# -------------
# epoch 18 || Epoch_D_Loss:0.0302 ||Epoch_G_Loss:0.4493
# timer:  0.4754 sec.
# -------------
# Epoch 19/500
# -------------
# （train）
# -------------
# epoch 19 || Epoch_D_Loss:0.0114 ||Epoch_G_Loss:0.6670
# timer:  0.4692 sec.
# -------------
# Epoch 20/500
# -------------
# （train）
# -------------
# epoch 20 || Epoch_D_Loss:0.0036 ||Epoch_G_Loss:0.7385
# timer:  0.4695 sec.
# -------------
# Epoch 21/500
# -------------
# （train）
# -------------
# epoch 21 || Epoch_D_Loss:0.0217 ||Epoch_G_Loss:0.7407
# timer:  0.4699 sec.
# -------------
# Epoch 22/500
# -------------
# （train）
# -------------
# epoch 22 || Epoch_D_Loss:0.0306 ||Epoch_G_Loss:0.5498
# timer:  0.4676 sec.
# -------------
# Epoch 23/500
# -------------
# （train）
# -------------
# epoch 23 || Epoch_D_Loss:0.0043 ||Epoch_G_Loss:0.7054
# timer:  0.4710 sec.
# -------------
# Epoch 24/500
# -------------
# （train）
# -------------
# epoch 24 || Epoch_D_Loss:0.0291 ||Epoch_G_Loss:0.6119
# timer:  0.4689 sec.
# -------------
# Epoch 25/500
# -------------
# （train）
# -------------
# epoch 25 || Epoch_D_Loss:0.0028 ||Epoch_G_Loss:0.7552
# timer:  0.4649 sec.
# -------------
# Epoch 26/500
# -------------
# （train）
# -------------
# epoch 26 || Epoch_D_Loss:0.0387 ||Epoch_G_Loss:0.5313
# timer:  0.4632 sec.
# -------------
# Epoch 27/500
# -------------
# （train）
# -------------
# epoch 27 || Epoch_D_Loss:0.0146 ||Epoch_G_Loss:0.6076
# timer:  0.4666 sec.
# -------------
# Epoch 28/500
# -------------
# （train）
# -------------
# epoch 28 || Epoch_D_Loss:0.0058 ||Epoch_G_Loss:0.7172
# timer:  0.4784 sec.
# -------------
# Epoch 29/500
# -------------
# （train）
# -------------
# epoch 29 || Epoch_D_Loss:0.0014 ||Epoch_G_Loss:0.8740
# timer:  0.4695 sec.
# -------------
# Epoch 30/500
# -------------
# （train）
# -------------
# epoch 30 || Epoch_D_Loss:0.0344 ||Epoch_G_Loss:0.5353
# timer:  0.4653 sec.
# -------------
# Epoch 31/500
# -------------
# （train）
# -------------
# epoch 31 || Epoch_D_Loss:0.0208 ||Epoch_G_Loss:0.6255
# timer:  0.4682 sec.
# -------------
# Epoch 32/500
# -------------
# （train）
# -------------
# epoch 32 || Epoch_D_Loss:0.0039 ||Epoch_G_Loss:0.7534
# timer:  0.4689 sec.
# -------------
# Epoch 33/500
# -------------
# （train）
# -------------
# epoch 33 || Epoch_D_Loss:0.0319 ||Epoch_G_Loss:0.5624
# timer:  0.4685 sec.
# -------------
# Epoch 34/500
# -------------
# （train）
# -------------
# epoch 34 || Epoch_D_Loss:0.0101 ||Epoch_G_Loss:0.6511
# timer:  0.4708 sec.
# -------------
# Epoch 35/500
# -------------
# （train）
# -------------
# epoch 35 || Epoch_D_Loss:0.0320 ||Epoch_G_Loss:0.5725
# timer:  0.4751 sec.
# -------------
# Epoch 36/500
# -------------
# （train）
# -------------
# epoch 36 || Epoch_D_Loss:0.0062 ||Epoch_G_Loss:0.6596
# timer:  0.4715 sec.
# -------------
# Epoch 37/500
# -------------
# （train）
# -------------
# epoch 37 || Epoch_D_Loss:0.0476 ||Epoch_G_Loss:0.5551
# timer:  0.4727 sec.
# -------------
# Epoch 38/500
# -------------
# （train）
# -------------
# epoch 38 || Epoch_D_Loss:0.0055 ||Epoch_G_Loss:0.6224
# timer:  0.4637 sec.
# -------------
# Epoch 39/500
# -------------
# （train）
# -------------
# epoch 39 || Epoch_D_Loss:0.0028 ||Epoch_G_Loss:0.7250
# timer:  0.4737 sec.
# -------------
# Epoch 40/500
# -------------
# （train）
# -------------
# epoch 40 || Epoch_D_Loss:0.0013 ||Epoch_G_Loss:0.7907
# timer:  0.4699 sec.
# -------------
# Epoch 41/500
# -------------
# （train）
# -------------
# epoch 41 || Epoch_D_Loss:0.0687 ||Epoch_G_Loss:0.7321
# timer:  0.4784 sec.
# -------------
# Epoch 42/500
# -------------
# （train）
# -------------
# epoch 42 || Epoch_D_Loss:0.0177 ||Epoch_G_Loss:0.4677
# timer:  0.4680 sec.
# -------------
# Epoch 43/500
# -------------
# （train）
# -------------
# epoch 43 || Epoch_D_Loss:0.0060 ||Epoch_G_Loss:0.6862
# timer:  0.4652 sec.
# -------------
# Epoch 44/500
# -------------
# （train）
# -------------
# epoch 44 || Epoch_D_Loss:0.0023 ||Epoch_G_Loss:0.8120
# timer:  0.4673 sec.
# -------------
# Epoch 45/500
# -------------
# （train）
# -------------
# epoch 45 || Epoch_D_Loss:0.0485 ||Epoch_G_Loss:0.6178
# timer:  0.4696 sec.
# -------------
# Epoch 46/500
# -------------
# （train）
# -------------
# epoch 46 || Epoch_D_Loss:0.0208 ||Epoch_G_Loss:0.4534
# timer:  0.4761 sec.
# -------------
# Epoch 47/500
# -------------
# （train）
# -------------
# epoch 47 || Epoch_D_Loss:0.0052 ||Epoch_G_Loss:0.7625
# timer:  0.4699 sec.
# -------------
# Epoch 48/500
# -------------
# （train）
# -------------
# epoch 48 || Epoch_D_Loss:0.0302 ||Epoch_G_Loss:0.5652
# timer:  0.4680 sec.
# -------------
# Epoch 49/500
# -------------
# （train）
# -------------
# epoch 49 || Epoch_D_Loss:0.0027 ||Epoch_G_Loss:0.7208
# timer:  0.4763 sec.
# -------------
# Epoch 50/500
# -------------
# （train）
# -------------
# epoch 50 || Epoch_D_Loss:0.0244 ||Epoch_G_Loss:0.7075
# timer:  0.4915 sec.
# -------------
# Epoch 51/500
# -------------
# （train）
# -------------
# epoch 51 || Epoch_D_Loss:0.0098 ||Epoch_G_Loss:0.7392
# timer:  0.4729 sec.
# -------------
# Epoch 52/500
# -------------
# （train）
# -------------
# epoch 52 || Epoch_D_Loss:0.0256 ||Epoch_G_Loss:0.6964
# timer:  0.4797 sec.
# -------------
# Epoch 53/500
# -------------
# （train）
# -------------
# epoch 53 || Epoch_D_Loss:0.0235 ||Epoch_G_Loss:0.5814
# timer:  0.4723 sec.
# -------------
# Epoch 54/500
# -------------
# （train）
# -------------
# epoch 54 || Epoch_D_Loss:0.0058 ||Epoch_G_Loss:0.7396
# timer:  0.4788 sec.
# -------------
# Epoch 55/500
# -------------
# （train）
# -------------
# epoch 55 || Epoch_D_Loss:0.0030 ||Epoch_G_Loss:0.7709
# timer:  0.4721 sec.
# -------------
# Epoch 56/500
# -------------
# （train）
# -------------
# epoch 56 || Epoch_D_Loss:0.0228 ||Epoch_G_Loss:0.7074
# timer:  0.4940 sec.
# -------------
# Epoch 57/500
# -------------
# （train）
# -------------
# epoch 57 || Epoch_D_Loss:0.0174 ||Epoch_G_Loss:0.6634
# timer:  0.4683 sec.
# -------------
# Epoch 58/500
# -------------
# （train）
# -------------
# epoch 58 || Epoch_D_Loss:0.0043 ||Epoch_G_Loss:0.8359
# timer:  0.4876 sec.
# -------------
# Epoch 59/500
# -------------
# （train）
# -------------
# epoch 59 || Epoch_D_Loss:0.0320 ||Epoch_G_Loss:0.7030
# timer:  0.4768 sec.
# -------------
# Epoch 60/500
# -------------
# （train）
# -------------
# epoch 60 || Epoch_D_Loss:0.0170 ||Epoch_G_Loss:0.6347
# timer:  0.4835 sec.
# -------------
# Epoch 61/500
# -------------
# （train）
# -------------
# epoch 61 || Epoch_D_Loss:0.0015 ||Epoch_G_Loss:0.8465
# timer:  0.4725 sec.
# -------------
# Epoch 62/500
# -------------
# （train）
# -------------
# epoch 62 || Epoch_D_Loss:0.0616 ||Epoch_G_Loss:0.7454
# timer:  0.4826 sec.
# -------------
# Epoch 63/500
# -------------
# （train）
# -------------
# epoch 63 || Epoch_D_Loss:0.0186 ||Epoch_G_Loss:0.3835
# timer:  0.4705 sec.
# -------------
# Epoch 64/500
# -------------
# （train）
# -------------
# epoch 64 || Epoch_D_Loss:0.0065 ||Epoch_G_Loss:0.5656
# timer:  0.4798 sec.
# -------------
# Epoch 65/500
# -------------
# （train）
# -------------
# epoch 65 || Epoch_D_Loss:0.0105 ||Epoch_G_Loss:0.6528
# timer:  0.4730 sec.
# -------------
# Epoch 66/500
# -------------
# （train）
# -------------
# epoch 66 || Epoch_D_Loss:0.0043 ||Epoch_G_Loss:0.7052
# timer:  0.4717 sec.
# -------------
# Epoch 67/500
# -------------
# （train）
# -------------
# epoch 67 || Epoch_D_Loss:0.0021 ||Epoch_G_Loss:0.8024
# timer:  0.4721 sec.
# -------------
# Epoch 68/500
# -------------
# （train）
# -------------
# epoch 68 || Epoch_D_Loss:0.0729 ||Epoch_G_Loss:0.6451
# timer:  0.4721 sec.
# -------------
# Epoch 69/500
# -------------
# （train）
# -------------
# epoch 69 || Epoch_D_Loss:0.0101 ||Epoch_G_Loss:0.5453
# timer:  0.4723 sec.
# -------------
# Epoch 70/500
# -------------
# （train）
# -------------
# epoch 70 || Epoch_D_Loss:0.0027 ||Epoch_G_Loss:0.7224
# timer:  0.4677 sec.
# -------------
# Epoch 71/500
# -------------
# （train）
# -------------
# epoch 71 || Epoch_D_Loss:0.0025 ||Epoch_G_Loss:0.7056
# timer:  0.4738 sec.
# -------------
# Epoch 72/500
# -------------
# （train）
# -------------
# epoch 72 || Epoch_D_Loss:0.0446 ||Epoch_G_Loss:0.5629
# timer:  0.4624 sec.
# -------------
# Epoch 73/500
# -------------
# （train）
# -------------
# epoch 73 || Epoch_D_Loss:0.0044 ||Epoch_G_Loss:0.7471
# timer:  0.4738 sec.
# -------------
# Epoch 74/500
# -------------
# （train）
# -------------
# epoch 74 || Epoch_D_Loss:0.0211 ||Epoch_G_Loss:0.7542
# timer:  0.4632 sec.
# -------------
# Epoch 75/500
# -------------
# （train）
# -------------
# epoch 75 || Epoch_D_Loss:0.0169 ||Epoch_G_Loss:0.5974
# timer:  0.4728 sec.
# -------------
# Epoch 76/500
# -------------
# （train）
# -------------
# epoch 76 || Epoch_D_Loss:0.0023 ||Epoch_G_Loss:0.8389
# timer:  0.4679 sec.
# -------------
# Epoch 77/500
# -------------
# （train）
# -------------
# epoch 77 || Epoch_D_Loss:0.0289 ||Epoch_G_Loss:0.7055
# timer:  0.4658 sec.
# -------------
# Epoch 78/500
# -------------
# （train）
# -------------
# epoch 78 || Epoch_D_Loss:0.0048 ||Epoch_G_Loss:0.7713
# timer:  0.4782 sec.
# -------------
# Epoch 79/500
# -------------
# （train）
# -------------
# epoch 79 || Epoch_D_Loss:0.0085 ||Epoch_G_Loss:0.8144
# timer:  0.4658 sec.
# -------------
# Epoch 80/500
# -------------
# （train）
# -------------
# epoch 80 || Epoch_D_Loss:0.0115 ||Epoch_G_Loss:0.8175
# timer:  0.4777 sec.
# -------------
# Epoch 81/500
# -------------
# （train）
# -------------
# epoch 81 || Epoch_D_Loss:0.0488 ||Epoch_G_Loss:0.5820
# timer:  0.4613 sec.
# -------------
# Epoch 82/500
# -------------
# （train）
# -------------
# epoch 82 || Epoch_D_Loss:0.0114 ||Epoch_G_Loss:0.5105
# timer:  0.4795 sec.
# -------------
# Epoch 83/500
# -------------
# （train）
# -------------
# epoch 83 || Epoch_D_Loss:0.0049 ||Epoch_G_Loss:0.6287
# timer:  0.4732 sec.
# -------------
# Epoch 84/500
# -------------
# （train）
# -------------
# epoch 84 || Epoch_D_Loss:0.0362 ||Epoch_G_Loss:0.6815
# timer:  0.4784 sec.
# -------------
# Epoch 85/500
# -------------
# （train）
# -------------
# epoch 85 || Epoch_D_Loss:0.0075 ||Epoch_G_Loss:0.6435
# timer:  0.4681 sec.
# -------------
# Epoch 86/500
# -------------
# （train）
# -------------
# epoch 86 || Epoch_D_Loss:0.0016 ||Epoch_G_Loss:0.8326
# timer:  0.4704 sec.
# -------------
# Epoch 87/500
# -------------
# （train）
# -------------
# epoch 87 || Epoch_D_Loss:0.0332 ||Epoch_G_Loss:0.7725
# timer:  0.4660 sec.
# -------------
# Epoch 88/500
# -------------
# （train）
# -------------
# epoch 88 || Epoch_D_Loss:0.0291 ||Epoch_G_Loss:0.4543
# timer:  0.4598 sec.
# -------------
# Epoch 89/500
# -------------
# （train）
# -------------
# epoch 89 || Epoch_D_Loss:0.0029 ||Epoch_G_Loss:0.7241
# timer:  0.4614 sec.
# -------------
# Epoch 90/500
# -------------
# （train）
# -------------
# epoch 90 || Epoch_D_Loss:0.0014 ||Epoch_G_Loss:0.8225
# timer:  0.4707 sec.
# -------------
# Epoch 91/500
# -------------
# （train）
# -------------
# epoch 91 || Epoch_D_Loss:0.0486 ||Epoch_G_Loss:0.6077
# timer:  0.4634 sec.
# -------------
# Epoch 92/500
# -------------
# （train）
# -------------
# epoch 92 || Epoch_D_Loss:0.0048 ||Epoch_G_Loss:0.5893
# timer:  0.4707 sec.
# -------------
# Epoch 93/500
# -------------
# （train）
# -------------
# epoch 93 || Epoch_D_Loss:0.0025 ||Epoch_G_Loss:0.7990
# timer:  0.4637 sec.
# -------------
# Epoch 94/500
# -------------
# （train）
# -------------
# epoch 94 || Epoch_D_Loss:0.0337 ||Epoch_G_Loss:0.8406
# timer:  0.4676 sec.
# -------------
# Epoch 95/500
# -------------
# （train）
# -------------
# epoch 95 || Epoch_D_Loss:0.0090 ||Epoch_G_Loss:0.7279
# timer:  0.4708 sec.
# -------------
# Epoch 96/500
# -------------
# （train）
# -------------
# epoch 96 || Epoch_D_Loss:0.0016 ||Epoch_G_Loss:0.8017
# timer:  0.4711 sec.
# -------------
# Epoch 97/500
# -------------
# （train）
# -------------
# epoch 97 || Epoch_D_Loss:0.0017 ||Epoch_G_Loss:0.8990
# timer:  0.4710 sec.
# -------------
# Epoch 98/500
# -------------
# （train）
# -------------
# epoch 98 || Epoch_D_Loss:0.0327 ||Epoch_G_Loss:0.7948
# timer:  0.4711 sec.
# -------------
# Epoch 99/500
# -------------
# （train）
# -------------
# epoch 99 || Epoch_D_Loss:0.0099 ||Epoch_G_Loss:0.6375
# timer:  0.4634 sec.
# -------------
# Epoch 100/500
# -------------
# （train）
# -------------
# epoch 100 || Epoch_D_Loss:0.0122 ||Epoch_G_Loss:0.7760
# timer:  0.4714 sec.
# -------------
# Epoch 101/500
# -------------
# （train）
# -------------
# epoch 101 || Epoch_D_Loss:0.0073 ||Epoch_G_Loss:0.8090
# timer:  0.4730 sec.
# -------------
# Epoch 102/500
# -------------
# （train）
# -------------
# epoch 102 || Epoch_D_Loss:0.0009 ||Epoch_G_Loss:0.9805
# timer:  0.4674 sec.
# -------------
# Epoch 103/500
# -------------
# （train）
# -------------
# epoch 103 || Epoch_D_Loss:0.0013 ||Epoch_G_Loss:0.9574
# timer:  0.4736 sec.
# -------------
# Epoch 104/500
# -------------
# （train）
# -------------
# epoch 104 || Epoch_D_Loss:0.3066 ||Epoch_G_Loss:1.0146
# timer:  0.4658 sec.
# -------------
# Epoch 105/500
# -------------
# （train）
# -------------
# epoch 105 || Epoch_D_Loss:0.0193 ||Epoch_G_Loss:0.5157
# timer:  0.4709 sec.
# -------------
# Epoch 106/500
# -------------
# （train）
# -------------
# epoch 106 || Epoch_D_Loss:0.0054 ||Epoch_G_Loss:0.6186
# timer:  0.4625 sec.
# -------------
# Epoch 107/500
# -------------
# （train）
# -------------
# epoch 107 || Epoch_D_Loss:0.0028 ||Epoch_G_Loss:0.7209
# timer:  0.4615 sec.
# -------------
# Epoch 108/500
# -------------
# （train）
# -------------
# epoch 108 || Epoch_D_Loss:0.0020 ||Epoch_G_Loss:0.7238
# timer:  0.4646 sec.
# -------------
# Epoch 109/500
# -------------
# （train）
# -------------
# epoch 109 || Epoch_D_Loss:0.0089 ||Epoch_G_Loss:0.8660
# timer:  0.4648 sec.
# -------------
# Epoch 110/500
# -------------
# （train）
# -------------
# epoch 110 || Epoch_D_Loss:0.0179 ||Epoch_G_Loss:0.7821
# timer:  0.4674 sec.
# -------------
# Epoch 111/500
# -------------
# （train）
# -------------
# epoch 111 || Epoch_D_Loss:0.0027 ||Epoch_G_Loss:0.8473
# timer:  0.4670 sec.
# -------------
# Epoch 112/500
# -------------
# （train）
# -------------
# epoch 112 || Epoch_D_Loss:0.0288 ||Epoch_G_Loss:0.8083
# timer:  0.4701 sec.
# -------------
# Epoch 113/500
# -------------
# （train）
# -------------
# epoch 113 || Epoch_D_Loss:0.0187 ||Epoch_G_Loss:0.5680
# timer:  0.4689 sec.
# -------------
# Epoch 114/500
# -------------
# （train）
# -------------
# epoch 114 || Epoch_D_Loss:0.0025 ||Epoch_G_Loss:0.7199
# timer:  0.4708 sec.
# -------------
# Epoch 115/500
# -------------
# （train）
# -------------
# epoch 115 || Epoch_D_Loss:0.0013 ||Epoch_G_Loss:0.8414
# timer:  0.4833 sec.
# -------------
# Epoch 116/500
# -------------
# （train）
# -------------
# epoch 116 || Epoch_D_Loss:0.0011 ||Epoch_G_Loss:0.8978
# timer:  0.4689 sec.
# -------------
# Epoch 117/500
# -------------
# （train）
# -------------
# epoch 117 || Epoch_D_Loss:0.0976 ||Epoch_G_Loss:0.9056
# timer:  0.4703 sec.
# -------------
# Epoch 118/500
# -------------
# （train）
# -------------
# epoch 118 || Epoch_D_Loss:0.0113 ||Epoch_G_Loss:0.5877
# timer:  0.4743 sec.
# -------------
# Epoch 119/500
# -------------
# （train）
# -------------
# epoch 119 || Epoch_D_Loss:0.0039 ||Epoch_G_Loss:0.6728
# timer:  0.4750 sec.
# -------------
# Epoch 120/500
# -------------
# （train）
# -------------
# epoch 120 || Epoch_D_Loss:0.0021 ||Epoch_G_Loss:0.7517
# timer:  0.4694 sec.
# -------------
# Epoch 121/500
# -------------
# （train）
# -------------
# epoch 121 || Epoch_D_Loss:0.0012 ||Epoch_G_Loss:0.8379
# timer:  0.4928 sec.
# -------------
# Epoch 122/500
# -------------
# （train）
# -------------
# epoch 122 || Epoch_D_Loss:0.0785 ||Epoch_G_Loss:0.8900
# timer:  0.4848 sec.
# -------------
# Epoch 123/500
# -------------
# （train）
# -------------
# epoch 123 || Epoch_D_Loss:0.0204 ||Epoch_G_Loss:0.5251
# timer:  0.4758 sec.
# -------------
# Epoch 124/500
# -------------
# （train）
# -------------
# epoch 124 || Epoch_D_Loss:0.0036 ||Epoch_G_Loss:0.6584
# timer:  0.4677 sec.
# -------------
# Epoch 125/500
# -------------
# （train）
# -------------
# epoch 125 || Epoch_D_Loss:0.0017 ||Epoch_G_Loss:0.7466
# timer:  0.4715 sec.
# -------------
# Epoch 126/500
# -------------
# （train）
# -------------
# epoch 126 || Epoch_D_Loss:0.0105 ||Epoch_G_Loss:0.8143
# timer:  0.4769 sec.
# -------------
# Epoch 127/500
# -------------
# （train）
# -------------
# epoch 127 || Epoch_D_Loss:0.0306 ||Epoch_G_Loss:0.7220
# timer:  0.4708 sec.
# -------------
# Epoch 128/500
# -------------
# （train）
# -------------
# epoch 128 || Epoch_D_Loss:0.0028 ||Epoch_G_Loss:0.7429
# timer:  0.4675 sec.
# -------------
# Epoch 129/500
# -------------
# （train）
# -------------
# epoch 129 || Epoch_D_Loss:0.0010 ||Epoch_G_Loss:0.8366
# timer:  0.4717 sec.
# -------------
# Epoch 130/500
# -------------
# （train）
# -------------
# epoch 130 || Epoch_D_Loss:0.0575 ||Epoch_G_Loss:0.8769
# timer:  0.4752 sec.
# -------------
# Epoch 131/500
# -------------
# （train）
# -------------
# epoch 131 || Epoch_D_Loss:0.0123 ||Epoch_G_Loss:0.5888
# timer:  0.4747 sec.
# -------------
# Epoch 132/500
# -------------
# （train）
# -------------
# epoch 132 || Epoch_D_Loss:0.0040 ||Epoch_G_Loss:0.7106
# timer:  0.4696 sec.
# -------------
# Epoch 133/500
# -------------
# （train）
# -------------
# epoch 133 || Epoch_D_Loss:0.0024 ||Epoch_G_Loss:0.7883
# timer:  0.4735 sec.
# -------------
# Epoch 134/500
# -------------
# （train）
# -------------
# epoch 134 || Epoch_D_Loss:0.0026 ||Epoch_G_Loss:0.8329
# timer:  0.4738 sec.
# -------------
# Epoch 135/500
# -------------
# （train）
# -------------
# epoch 135 || Epoch_D_Loss:0.0651 ||Epoch_G_Loss:0.6438
# timer:  0.4747 sec.
# -------------
# Epoch 136/500
# -------------
# （train）
# -------------
# epoch 136 || Epoch_D_Loss:0.0058 ||Epoch_G_Loss:0.6474
# timer:  0.4750 sec.
# -------------
# Epoch 137/500
# -------------
# （train）
# -------------
# epoch 137 || Epoch_D_Loss:0.0021 ||Epoch_G_Loss:0.7967
# timer:  0.4668 sec.
# -------------
# Epoch 138/500
# -------------
# （train）
# -------------
# epoch 138 || Epoch_D_Loss:0.0012 ||Epoch_G_Loss:0.8493
# timer:  0.4720 sec.
# -------------
# Epoch 139/500
# -------------
# （train）
# -------------
# epoch 139 || Epoch_D_Loss:0.0006 ||Epoch_G_Loss:0.8560
# timer:  0.4638 sec.
# -------------
# Epoch 140/500
# -------------
# （train）
# -------------
# epoch 140 || Epoch_D_Loss:0.0483 ||Epoch_G_Loss:0.7766
# timer:  0.4674 sec.
# -------------
# Epoch 141/500
# -------------
# （train）
# -------------
# epoch 141 || Epoch_D_Loss:0.0076 ||Epoch_G_Loss:0.6524
# timer:  0.4640 sec.
# -------------
# Epoch 142/500
# -------------
# （train）
# -------------
# epoch 142 || Epoch_D_Loss:0.0017 ||Epoch_G_Loss:0.7965
# timer:  0.4641 sec.
# -------------
# Epoch 143/500
# -------------
# （train）
# -------------
# epoch 143 || Epoch_D_Loss:0.0009 ||Epoch_G_Loss:0.8738
# timer:  0.4717 sec.
# -------------
# Epoch 144/500
# -------------
# （train）
# -------------
# epoch 144 || Epoch_D_Loss:0.0905 ||Epoch_G_Loss:0.6942
# timer:  0.4644 sec.
# -------------
# Epoch 145/500
# -------------
# （train）
# -------------
# epoch 145 || Epoch_D_Loss:0.0081 ||Epoch_G_Loss:0.5853
# timer:  0.4768 sec.
# -------------
# Epoch 146/500
# -------------
# （train）
# -------------
# epoch 146 || Epoch_D_Loss:0.0044 ||Epoch_G_Loss:0.6845
# timer:  0.4630 sec.
# -------------
# Epoch 147/500
# -------------
# （train）
# -------------
# epoch 147 || Epoch_D_Loss:0.0020 ||Epoch_G_Loss:0.7809
# timer:  0.4776 sec.
# -------------
# Epoch 148/500
# -------------
# （train）
# -------------
# epoch 148 || Epoch_D_Loss:0.0013 ||Epoch_G_Loss:0.8853
# timer:  0.4744 sec.
# -------------
# Epoch 149/500
# -------------
# （train）
# -------------
# epoch 149 || Epoch_D_Loss:0.0014 ||Epoch_G_Loss:0.9732
# timer:  0.4695 sec.
# -------------
# Epoch 150/500
# -------------
# （train）
# -------------
# epoch 150 || Epoch_D_Loss:0.0916 ||Epoch_G_Loss:0.5121
# timer:  0.4647 sec.
# -------------
# Epoch 151/500
# -------------
# （train）
# -------------
# epoch 151 || Epoch_D_Loss:0.0054 ||Epoch_G_Loss:0.6045
# timer:  0.4725 sec.
# -------------
# Epoch 152/500
# -------------
# （train）
# -------------
# epoch 152 || Epoch_D_Loss:0.0032 ||Epoch_G_Loss:0.7122
# timer:  0.4672 sec.
# -------------
# Epoch 153/500
# -------------
# （train）
# -------------
# epoch 153 || Epoch_D_Loss:0.0017 ||Epoch_G_Loss:0.7884
# timer:  0.4608 sec.
# -------------
# Epoch 154/500
# -------------
# （train）
# -------------
# epoch 154 || Epoch_D_Loss:0.0012 ||Epoch_G_Loss:0.8863
# timer:  0.4661 sec.
# -------------
# Epoch 155/500
# -------------
# （train）
# -------------
# epoch 155 || Epoch_D_Loss:0.0007 ||Epoch_G_Loss:0.9125
# timer:  0.4739 sec.
# -------------
# Epoch 156/500
# -------------
# （train）
# -------------
# epoch 156 || Epoch_D_Loss:0.0078 ||Epoch_G_Loss:1.1488
# timer:  0.4710 sec.
# -------------
# Epoch 157/500
# -------------
# （train）
# -------------
# epoch 157 || Epoch_D_Loss:0.0916 ||Epoch_G_Loss:0.5491
# timer:  0.4666 sec.
# -------------
# Epoch 158/500
# -------------
# （train）
# -------------
# epoch 158 || Epoch_D_Loss:0.0057 ||Epoch_G_Loss:0.6372
# timer:  0.4695 sec.
# -------------
# Epoch 159/500
# -------------
# （train）
# -------------
# epoch 159 || Epoch_D_Loss:0.0021 ||Epoch_G_Loss:0.7772
# timer:  0.4682 sec.
# -------------
# Epoch 160/500
# -------------
# （train）
# -------------
# epoch 160 || Epoch_D_Loss:0.0021 ||Epoch_G_Loss:0.8388
# timer:  0.4720 sec.
# -------------
# Epoch 161/500
# -------------
# （train）
# -------------
# epoch 161 || Epoch_D_Loss:0.0487 ||Epoch_G_Loss:0.7926
# timer:  0.4684 sec.
# -------------
# Epoch 162/500
# -------------
# （train）
# -------------
# epoch 162 || Epoch_D_Loss:0.0123 ||Epoch_G_Loss:0.6297
# timer:  0.4700 sec.
# -------------
# Epoch 163/500
# -------------
# （train）
# -------------
# epoch 163 || Epoch_D_Loss:0.0020 ||Epoch_G_Loss:0.8043
# timer:  0.4739 sec.
# -------------
# Epoch 164/500
# -------------
# （train）
# -------------
# epoch 164 || Epoch_D_Loss:0.0012 ||Epoch_G_Loss:0.8682
# timer:  0.4787 sec.
# -------------
# Epoch 165/500
# -------------
# （train）
# -------------
# epoch 165 || Epoch_D_Loss:0.0010 ||Epoch_G_Loss:0.9189
# timer:  0.4664 sec.
# -------------
# Epoch 166/500
# -------------
# （train）
# -------------
# epoch 166 || Epoch_D_Loss:0.0097 ||Epoch_G_Loss:0.9621
# timer:  0.4655 sec.
# -------------
# Epoch 167/500
# -------------
# （train）
# -------------
# epoch 167 || Epoch_D_Loss:0.0477 ||Epoch_G_Loss:0.6378
# timer:  0.4776 sec.
# -------------
# Epoch 168/500
# -------------
# （train）
# -------------
# epoch 168 || Epoch_D_Loss:0.0028 ||Epoch_G_Loss:0.7889
# timer:  0.4654 sec.
# -------------
# Epoch 169/500
# -------------
# （train）
# -------------
# epoch 169 || Epoch_D_Loss:0.0043 ||Epoch_G_Loss:0.8629
# timer:  0.4858 sec.
# -------------
# Epoch 170/500
# -------------
# （train）
# -------------
# epoch 170 || Epoch_D_Loss:0.0379 ||Epoch_G_Loss:0.6810
# timer:  0.4730 sec.
# -------------
# Epoch 171/500
# -------------
# （train）
# -------------
# epoch 171 || Epoch_D_Loss:0.0055 ||Epoch_G_Loss:0.6824
# timer:  0.4694 sec.
# -------------
# Epoch 172/500
# -------------
# （train）
# -------------
# epoch 172 || Epoch_D_Loss:0.0018 ||Epoch_G_Loss:0.8089
# timer:  0.4707 sec.
# -------------
# Epoch 173/500
# -------------
# （train）
# -------------
# epoch 173 || Epoch_D_Loss:0.0013 ||Epoch_G_Loss:0.9151
# timer:  0.4757 sec.
# -------------
# Epoch 174/500
# -------------
# （train）
# -------------
# epoch 174 || Epoch_D_Loss:0.0007 ||Epoch_G_Loss:0.9462
# timer:  0.4733 sec.
# -------------
# Epoch 175/500
# -------------
# （train）
# -------------
# epoch 175 || Epoch_D_Loss:0.0635 ||Epoch_G_Loss:0.7363
# timer:  0.4733 sec.
# -------------
# Epoch 176/500
# -------------
# （train）
# -------------
# epoch 176 || Epoch_D_Loss:0.0061 ||Epoch_G_Loss:0.6431
# timer:  0.4680 sec.
# -------------
# Epoch 177/500
# -------------
# （train）
# -------------
# epoch 177 || Epoch_D_Loss:0.0023 ||Epoch_G_Loss:0.7518
# timer:  0.4772 sec.
# -------------
# Epoch 178/500
# -------------
# （train）
# -------------
# epoch 178 || Epoch_D_Loss:0.0314 ||Epoch_G_Loss:0.8677
# timer:  0.4615 sec.
# -------------
# Epoch 179/500
# -------------
# （train）
# -------------
# epoch 179 || Epoch_D_Loss:0.0227 ||Epoch_G_Loss:0.5609
# timer:  0.4697 sec.
# -------------
# Epoch 180/500
# -------------
# （train）
# -------------
# epoch 180 || Epoch_D_Loss:0.0027 ||Epoch_G_Loss:0.7548
# timer:  0.4663 sec.
# -------------
# Epoch 181/500
# -------------
# （train）
# -------------
# epoch 181 || Epoch_D_Loss:0.0013 ||Epoch_G_Loss:0.8486
# timer:  0.4661 sec.
# -------------
# Epoch 182/500
# -------------
# （train）
# -------------
# epoch 182 || Epoch_D_Loss:0.0007 ||Epoch_G_Loss:0.8909
# timer:  0.4739 sec.
# -------------
# Epoch 183/500
# -------------
# （train）
# -------------
# epoch 183 || Epoch_D_Loss:0.0496 ||Epoch_G_Loss:0.8946
# timer:  0.4668 sec.
# -------------
# Epoch 184/500
# -------------
# （train）
# -------------
# epoch 184 || Epoch_D_Loss:0.0242 ||Epoch_G_Loss:0.5086
# timer:  0.4746 sec.
# -------------
# Epoch 185/500
# -------------
# （train）
# -------------
# epoch 185 || Epoch_D_Loss:0.0045 ||Epoch_G_Loss:0.8164
# timer:  0.4633 sec.
# -------------
# Epoch 186/500
# -------------
# （train）
# -------------
# epoch 186 || Epoch_D_Loss:0.0011 ||Epoch_G_Loss:0.8613
# timer:  0.4638 sec.
# -------------
# Epoch 187/500
# -------------
# （train）
# -------------
# epoch 187 || Epoch_D_Loss:0.0007 ||Epoch_G_Loss:0.9018
# timer:  0.4632 sec.
# -------------
# Epoch 188/500
# -------------
# （train）
# -------------
# epoch 188 || Epoch_D_Loss:0.0533 ||Epoch_G_Loss:0.6569
# timer:  0.4636 sec.
# -------------
# Epoch 189/500
# -------------
# （train）
# -------------
# epoch 189 || Epoch_D_Loss:0.0049 ||Epoch_G_Loss:0.6297
# timer:  0.4624 sec.
# -------------
# Epoch 190/500
# -------------
# （train）
# -------------
# epoch 190 || Epoch_D_Loss:0.0016 ||Epoch_G_Loss:0.8254
# timer:  0.4710 sec.
# -------------
# Epoch 191/500
# -------------
# （train）
# -------------
# epoch 191 || Epoch_D_Loss:0.0065 ||Epoch_G_Loss:0.8482
# timer:  0.4658 sec.
# -------------
# Epoch 192/500
# -------------
# （train）
# -------------
# epoch 192 || Epoch_D_Loss:0.0090 ||Epoch_G_Loss:0.8798
# timer:  0.4664 sec.
# -------------
# Epoch 193/500
# -------------
# （train）
# -------------
# epoch 193 || Epoch_D_Loss:0.0008 ||Epoch_G_Loss:0.9764
# timer:  0.4763 sec.
# -------------
# Epoch 194/500
# -------------
# （train）
# -------------
# epoch 194 || Epoch_D_Loss:0.0020 ||Epoch_G_Loss:1.0614
# timer:  0.4693 sec.
# -------------
# Epoch 195/500
# -------------
# （train）
# -------------
# epoch 195 || Epoch_D_Loss:0.0594 ||Epoch_G_Loss:0.5337
# timer:  0.4676 sec.
# -------------
# Epoch 196/500
# -------------
# （train）
# -------------
# epoch 196 || Epoch_D_Loss:0.0035 ||Epoch_G_Loss:0.7155
# timer:  0.4668 sec.
# -------------
# Epoch 197/500
# -------------
# （train）
# -------------
# epoch 197 || Epoch_D_Loss:0.0012 ||Epoch_G_Loss:0.8670
# timer:  0.4715 sec.
# -------------
# Epoch 198/500
# -------------
# （train）
# -------------
# epoch 198 || Epoch_D_Loss:0.0012 ||Epoch_G_Loss:0.9612
# timer:  0.4717 sec.
# -------------
# Epoch 199/500
# -------------
# （train）
# -------------
# epoch 199 || Epoch_D_Loss:0.0474 ||Epoch_G_Loss:0.6971
# timer:  0.4730 sec.
# -------------
# Epoch 200/500
# -------------
# （train）
# -------------
# epoch 200 || Epoch_D_Loss:0.0061 ||Epoch_G_Loss:0.6088
# timer:  0.4717 sec.
# -------------
# Epoch 201/500
# -------------
# （train）
# -------------
# epoch 201 || Epoch_D_Loss:0.0020 ||Epoch_G_Loss:0.7852
# timer:  0.4714 sec.
# -------------
# Epoch 202/500
# -------------
# （train）
# -------------
# epoch 202 || Epoch_D_Loss:0.0030 ||Epoch_G_Loss:1.0634
# timer:  0.4711 sec.
# -------------
# Epoch 203/500
# -------------
# （train）
# -------------
# epoch 203 || Epoch_D_Loss:0.0786 ||Epoch_G_Loss:0.5698
# timer:  0.4688 sec.
# -------------
# Epoch 204/500
# -------------
# （train）
# -------------
# epoch 204 || Epoch_D_Loss:0.0042 ||Epoch_G_Loss:0.6764
# timer:  0.4585 sec.
# -------------
# Epoch 205/500
# -------------
# （train）
# -------------
# epoch 205 || Epoch_D_Loss:0.0022 ||Epoch_G_Loss:0.7651
# timer:  0.4668 sec.
# -------------
# Epoch 206/500
# -------------
# （train）
# -------------
# epoch 206 || Epoch_D_Loss:0.0014 ||Epoch_G_Loss:0.8514
# timer:  0.4697 sec.
# -------------
# Epoch 207/500
# -------------
# （train）
# -------------
# epoch 207 || Epoch_D_Loss:0.0363 ||Epoch_G_Loss:0.6761
# timer:  0.4721 sec.
# -------------
# Epoch 208/500
# -------------
# （train）
# -------------
# epoch 208 || Epoch_D_Loss:0.0022 ||Epoch_G_Loss:0.7418
# timer:  0.4675 sec.
# -------------
# Epoch 209/500
# -------------
# （train）
# -------------
# epoch 209 || Epoch_D_Loss:0.0030 ||Epoch_G_Loss:0.8611
# timer:  0.4675 sec.
# -------------
# Epoch 210/500
# -------------
# （train）
# -------------
# epoch 210 || Epoch_D_Loss:0.0202 ||Epoch_G_Loss:0.8294
# timer:  0.4640 sec.
# -------------
# Epoch 211/500
# -------------
# （train）
# -------------
# epoch 211 || Epoch_D_Loss:0.0013 ||Epoch_G_Loss:0.8869
# timer:  0.4711 sec.
# -------------
# Epoch 212/500
# -------------
# （train）
# -------------
# epoch 212 || Epoch_D_Loss:0.0303 ||Epoch_G_Loss:0.9901
# timer:  0.4684 sec.
# -------------
# Epoch 213/500
# -------------
# （train）
# -------------
# epoch 213 || Epoch_D_Loss:0.0090 ||Epoch_G_Loss:0.6211
# timer:  0.4696 sec.
# -------------
# Epoch 214/500
# -------------
# （train）
# -------------
# epoch 214 || Epoch_D_Loss:0.0022 ||Epoch_G_Loss:0.8367
# timer:  0.4622 sec.
# -------------
# Epoch 215/500
# -------------
# （train）
# -------------
# epoch 215 || Epoch_D_Loss:0.0058 ||Epoch_G_Loss:0.7808
# timer:  0.4595 sec.
# -------------
# Epoch 216/500
# -------------
# （train）
# -------------
# epoch 216 || Epoch_D_Loss:0.0142 ||Epoch_G_Loss:0.9316
# timer:  0.4634 sec.
# -------------
# Epoch 217/500
# -------------
# （train）
# -------------
# epoch 217 || Epoch_D_Loss:0.0416 ||Epoch_G_Loss:0.5397
# timer:  0.4664 sec.
# -------------
# Epoch 218/500
# -------------
# （train）
# -------------
# epoch 218 || Epoch_D_Loss:0.0031 ||Epoch_G_Loss:0.7871
# timer:  0.4676 sec.
# -------------
# Epoch 219/500
# -------------
# （train）
# -------------
# epoch 219 || Epoch_D_Loss:0.0011 ||Epoch_G_Loss:0.8740
# timer:  0.4647 sec.
# -------------
# Epoch 220/500
# -------------
# （train）
# -------------
# epoch 220 || Epoch_D_Loss:0.0007 ||Epoch_G_Loss:0.9398
# timer:  0.4707 sec.
# -------------
# Epoch 221/500
# -------------
# （train）
# -------------
# epoch 221 || Epoch_D_Loss:0.0361 ||Epoch_G_Loss:0.7743
# timer:  0.4633 sec.
# -------------
# Epoch 222/500
# -------------
# （train）
# -------------
# epoch 222 || Epoch_D_Loss:0.0063 ||Epoch_G_Loss:0.8075
# timer:  0.4645 sec.
# -------------
# Epoch 223/500
# -------------
# （train）
# -------------
# epoch 223 || Epoch_D_Loss:0.0011 ||Epoch_G_Loss:0.8693
# timer:  0.4630 sec.
# -------------
# Epoch 224/500
# -------------
# （train）
# -------------
# epoch 224 || Epoch_D_Loss:0.0061 ||Epoch_G_Loss:0.9268
# timer:  0.4579 sec.
# -------------
# Epoch 225/500
# -------------
# （train）
# -------------
# epoch 225 || Epoch_D_Loss:0.0132 ||Epoch_G_Loss:0.8413
# timer:  0.4565 sec.
# -------------
# Epoch 226/500
# -------------
# （train）
# -------------
# epoch 226 || Epoch_D_Loss:0.0126 ||Epoch_G_Loss:0.7556
# timer:  0.4688 sec.
# -------------
# Epoch 227/500
# -------------
# （train）
# -------------
# epoch 227 || Epoch_D_Loss:0.0012 ||Epoch_G_Loss:0.8931
# timer:  0.4665 sec.
# -------------
# Epoch 228/500
# -------------
# （train）
# -------------
# epoch 228 || Epoch_D_Loss:0.0233 ||Epoch_G_Loss:0.8695
# timer:  0.4691 sec.
# -------------
# Epoch 229/500
# -------------
# （train）
# -------------
# epoch 229 || Epoch_D_Loss:0.0182 ||Epoch_G_Loss:0.8178
# timer:  0.4647 sec.
# -------------
# Epoch 230/500
# -------------
# （train）
# -------------
# epoch 230 || Epoch_D_Loss:0.0116 ||Epoch_G_Loss:0.6359
# timer:  0.4681 sec.
# -------------
# Epoch 231/500
# -------------
# （train）
# -------------
# epoch 231 || Epoch_D_Loss:0.0020 ||Epoch_G_Loss:0.8571
# timer:  0.4619 sec.
# -------------
# Epoch 232/500
# -------------
# （train）
# -------------
# epoch 232 || Epoch_D_Loss:0.0014 ||Epoch_G_Loss:0.8937
# timer:  0.4668 sec.
# -------------
# Epoch 233/500
# -------------
# （train）
# -------------
# epoch 233 || Epoch_D_Loss:0.0093 ||Epoch_G_Loss:0.8713
# timer:  0.4629 sec.
# -------------
# Epoch 234/500
# -------------
# （train）
# -------------
# epoch 234 || Epoch_D_Loss:0.0284 ||Epoch_G_Loss:0.6574
# timer:  0.4712 sec.
# -------------
# Epoch 235/500
# -------------
# （train）
# -------------
# epoch 235 || Epoch_D_Loss:0.0016 ||Epoch_G_Loss:0.8952
# timer:  0.4672 sec.
# -------------
# Epoch 236/500
# -------------
# （train）
# -------------
# epoch 236 || Epoch_D_Loss:0.0014 ||Epoch_G_Loss:0.9404
# timer:  0.4741 sec.
# -------------
# Epoch 237/500
# -------------
# （train）
# -------------
# epoch 237 || Epoch_D_Loss:0.0371 ||Epoch_G_Loss:0.5725
# timer:  0.4615 sec.
# -------------
# Epoch 238/500
# -------------
# （train）
# -------------
# epoch 238 || Epoch_D_Loss:0.0030 ||Epoch_G_Loss:0.7888
# timer:  0.4702 sec.
# -------------
# Epoch 239/500
# -------------
# （train）
# -------------
# epoch 239 || Epoch_D_Loss:0.0006 ||Epoch_G_Loss:0.9777
# timer:  0.4689 sec.
# -------------
# Epoch 240/500
# -------------
# （train）
# -------------
# epoch 240 || Epoch_D_Loss:0.0005 ||Epoch_G_Loss:1.0340
# timer:  0.4687 sec.
# -------------
# Epoch 241/500
# -------------
# （train）
# -------------
# epoch 241 || Epoch_D_Loss:0.0005 ||Epoch_G_Loss:1.0746
# timer:  0.4743 sec.
# -------------
# Epoch 242/500
# -------------
# （train）
# -------------
# epoch 242 || Epoch_D_Loss:0.0427 ||Epoch_G_Loss:0.7632
# timer:  0.4682 sec.
# -------------
# Epoch 243/500
# -------------
# （train）
# -------------
# epoch 243 || Epoch_D_Loss:0.0065 ||Epoch_G_Loss:0.5898
# timer:  0.4744 sec.
# -------------
# Epoch 244/500
# -------------
# （train）
# -------------
# epoch 244 || Epoch_D_Loss:0.0044 ||Epoch_G_Loss:0.7640
# timer:  0.4620 sec.
# -------------
# Epoch 245/500
# -------------
# （train）
# -------------
# epoch 245 || Epoch_D_Loss:0.0020 ||Epoch_G_Loss:0.8522
# timer:  0.4679 sec.
# -------------
# Epoch 246/500
# -------------
# （train）
# -------------
# epoch 246 || Epoch_D_Loss:0.0015 ||Epoch_G_Loss:0.9370
# timer:  0.4720 sec.
# -------------
# Epoch 247/500
# -------------
# （train）
# -------------
# epoch 247 || Epoch_D_Loss:0.0005 ||Epoch_G_Loss:0.9528
# timer:  0.4695 sec.
# -------------
# Epoch 248/500
# -------------
# （train）
# -------------
# epoch 248 || Epoch_D_Loss:0.0498 ||Epoch_G_Loss:1.0056
# timer:  0.4775 sec.
# -------------
# Epoch 249/500
# -------------
# （train）
# -------------
# epoch 249 || Epoch_D_Loss:0.0138 ||Epoch_G_Loss:0.5884
# timer:  0.4858 sec.
# -------------
# Epoch 250/500
# -------------
# （train）
# -------------
# epoch 250 || Epoch_D_Loss:0.0023 ||Epoch_G_Loss:0.7668
# timer:  0.4698 sec.
# -------------
# Epoch 251/500
# -------------
# （train）
# -------------
# epoch 251 || Epoch_D_Loss:0.0028 ||Epoch_G_Loss:0.9136
# timer:  0.4666 sec.
# -------------
# Epoch 252/500
# -------------
# （train）
# -------------
# epoch 252 || Epoch_D_Loss:0.0007 ||Epoch_G_Loss:1.0070
# timer:  0.4670 sec.
# -------------
# Epoch 253/500
# -------------
# （train）
# -------------
# epoch 253 || Epoch_D_Loss:0.0003 ||Epoch_G_Loss:1.0557
# timer:  0.4629 sec.
# -------------
# Epoch 254/500
# -------------
# （train）
# -------------
# epoch 254 || Epoch_D_Loss:0.0032 ||Epoch_G_Loss:1.2277
# timer:  0.4720 sec.
# -------------
# Epoch 255/500
# -------------
# （train）
# -------------
# epoch 255 || Epoch_D_Loss:0.0433 ||Epoch_G_Loss:0.5890
# timer:  0.4644 sec.
# -------------
# Epoch 256/500
# -------------
# （train）
# -------------
# epoch 256 || Epoch_D_Loss:0.0030 ||Epoch_G_Loss:0.7422
# timer:  0.4711 sec.
# -------------
# Epoch 257/500
# -------------
# （train）
# -------------
# epoch 257 || Epoch_D_Loss:0.0027 ||Epoch_G_Loss:0.8778
# timer:  0.4689 sec.
# -------------
# Epoch 258/500
# -------------
# （train）
# -------------
# epoch 258 || Epoch_D_Loss:0.0009 ||Epoch_G_Loss:1.0087
# timer:  0.4772 sec.
# -------------
# Epoch 259/500
# -------------
# （train）
# -------------
# epoch 259 || Epoch_D_Loss:0.0006 ||Epoch_G_Loss:1.0456
# timer:  0.4678 sec.
# -------------
# Epoch 260/500
# -------------
# （train）
# -------------
# epoch 260 || Epoch_D_Loss:0.0666 ||Epoch_G_Loss:1.1781
# timer:  0.4758 sec.
# -------------
# Epoch 261/500
# -------------
# （train）
# -------------
# epoch 261 || Epoch_D_Loss:0.0078 ||Epoch_G_Loss:0.7133
# timer:  0.4684 sec.
# -------------
# Epoch 262/500
# -------------
# （train）
# -------------
# epoch 262 || Epoch_D_Loss:0.0016 ||Epoch_G_Loss:0.7805
# timer:  0.4719 sec.
# -------------
# Epoch 263/500
# -------------
# （train）
# -------------
# epoch 263 || Epoch_D_Loss:0.0012 ||Epoch_G_Loss:0.9035
# timer:  0.4677 sec.
# -------------
# Epoch 264/500
# -------------
# （train）
# -------------
# epoch 264 || Epoch_D_Loss:0.0278 ||Epoch_G_Loss:1.0432
# timer:  0.4654 sec.
# -------------
# Epoch 265/500
# -------------
# （train）
# -------------
# epoch 265 || Epoch_D_Loss:0.0117 ||Epoch_G_Loss:0.7568
# timer:  0.4700 sec.
# -------------
# Epoch 266/500
# -------------
# （train）
# -------------
# epoch 266 || Epoch_D_Loss:0.0026 ||Epoch_G_Loss:0.9244
# timer:  0.4656 sec.
# -------------
# Epoch 267/500
# -------------
# （train）
# -------------
# epoch 267 || Epoch_D_Loss:0.0009 ||Epoch_G_Loss:0.9438
# timer:  0.4641 sec.
# -------------
# Epoch 268/500
# -------------
# （train）
# -------------
# epoch 268 || Epoch_D_Loss:0.0007 ||Epoch_G_Loss:0.9134
# timer:  0.4600 sec.
# -------------
# Epoch 269/500
# -------------
# （train）
# -------------
# epoch 269 || Epoch_D_Loss:0.0396 ||Epoch_G_Loss:0.7913
# timer:  0.4708 sec.
# -------------
# Epoch 270/500
# -------------
# （train）
# -------------
# epoch 270 || Epoch_D_Loss:0.0033 ||Epoch_G_Loss:0.6738
# timer:  0.4608 sec.
# -------------
# Epoch 271/500
# -------------
# （train）
# -------------
# epoch 271 || Epoch_D_Loss:0.0018 ||Epoch_G_Loss:0.8772
# timer:  0.4782 sec.
# -------------
# Epoch 272/500
# -------------
# （train）
# -------------
# epoch 272 || Epoch_D_Loss:0.0005 ||Epoch_G_Loss:0.9737
# timer:  0.4621 sec.
# -------------
# Epoch 273/500
# -------------
# （train）
# -------------
# epoch 273 || Epoch_D_Loss:0.0004 ||Epoch_G_Loss:1.0288
# timer:  0.4752 sec.
# -------------
# Epoch 274/500
# -------------
# （train）
# -------------
# epoch 274 || Epoch_D_Loss:0.0346 ||Epoch_G_Loss:0.7807
# timer:  0.4741 sec.
# -------------
# Epoch 275/500
# -------------
# （train）
# -------------
# epoch 275 || Epoch_D_Loss:0.0044 ||Epoch_G_Loss:0.8210
# timer:  0.4710 sec.
# -------------
# Epoch 276/500
# -------------
# （train）
# -------------
# epoch 276 || Epoch_D_Loss:0.0010 ||Epoch_G_Loss:1.0302
# timer:  0.4797 sec.
# -------------
# Epoch 277/500
# -------------
# （train）
# -------------
# epoch 277 || Epoch_D_Loss:0.0005 ||Epoch_G_Loss:1.0691
# timer:  0.4728 sec.
# -------------
# Epoch 278/500
# -------------
# （train）
# -------------
# epoch 278 || Epoch_D_Loss:0.1027 ||Epoch_G_Loss:0.9766
# timer:  0.4747 sec.
# -------------
# Epoch 279/500
# -------------
# （train）
# -------------
# epoch 279 || Epoch_D_Loss:0.0031 ||Epoch_G_Loss:0.7028
# timer:  0.4792 sec.
# -------------
# Epoch 280/500
# -------------
# （train）
# -------------
# epoch 280 || Epoch_D_Loss:0.0035 ||Epoch_G_Loss:0.8068
# timer:  0.4675 sec.
# -------------
# Epoch 281/500
# -------------
# （train）
# -------------
# epoch 281 || Epoch_D_Loss:0.0018 ||Epoch_G_Loss:0.8877
# timer:  0.4712 sec.
# -------------
# Epoch 282/500
# -------------
# （train）
# -------------
# epoch 282 || Epoch_D_Loss:0.0007 ||Epoch_G_Loss:0.9334
# timer:  0.4838 sec.
# -------------
# Epoch 283/500
# -------------
# （train）
# -------------
# epoch 283 || Epoch_D_Loss:0.0284 ||Epoch_G_Loss:1.0112
# timer:  0.4796 sec.
# -------------
# Epoch 284/500
# -------------
# （train）
# -------------
# epoch 284 || Epoch_D_Loss:0.0117 ||Epoch_G_Loss:0.6572
# timer:  0.4721 sec.
# -------------
# Epoch 285/500
# -------------
# （train）
# -------------
# epoch 285 || Epoch_D_Loss:0.0033 ||Epoch_G_Loss:0.8873
# timer:  0.4741 sec.
# -------------
# Epoch 286/500
# -------------
# （train）
# -------------
# epoch 286 || Epoch_D_Loss:0.0010 ||Epoch_G_Loss:0.9115
# timer:  0.4716 sec.
# -------------
# Epoch 287/500
# -------------
# （train）
# -------------
# epoch 287 || Epoch_D_Loss:0.0009 ||Epoch_G_Loss:1.0098
# timer:  0.4696 sec.
# -------------
# Epoch 288/500
# -------------
# （train）
# -------------
# epoch 288 || Epoch_D_Loss:0.0280 ||Epoch_G_Loss:0.9585
# timer:  0.4738 sec.
# -------------
# Epoch 289/500
# -------------
# （train）
# -------------
# epoch 289 || Epoch_D_Loss:0.0123 ||Epoch_G_Loss:0.6632
# timer:  0.4691 sec.
# -------------
# Epoch 290/500
# -------------
# （train）
# -------------
# epoch 290 || Epoch_D_Loss:0.0041 ||Epoch_G_Loss:0.9172
# timer:  0.4693 sec.
# -------------
# Epoch 291/500
# -------------
# （train）
# -------------
# epoch 291 || Epoch_D_Loss:0.0211 ||Epoch_G_Loss:0.8009
# timer:  0.4672 sec.
# -------------
# Epoch 292/500
# -------------
# （train）
# -------------
# epoch 292 || Epoch_D_Loss:0.0017 ||Epoch_G_Loss:0.8758
# timer:  0.4644 sec.
# -------------
# Epoch 293/500
# -------------
# （train）
# -------------
# epoch 293 || Epoch_D_Loss:0.0004 ||Epoch_G_Loss:0.9474
# timer:  0.4657 sec.
# -------------
# Epoch 294/500
# -------------
# （train）
# -------------
# epoch 294 || Epoch_D_Loss:0.0386 ||Epoch_G_Loss:0.8104
# timer:  0.4713 sec.
# -------------
# Epoch 295/500
# -------------
# （train）
# -------------
# epoch 295 || Epoch_D_Loss:0.0034 ||Epoch_G_Loss:0.6887
# timer:  0.4755 sec.
# -------------
# Epoch 296/500
# -------------
# （train）
# -------------
# epoch 296 || Epoch_D_Loss:0.0015 ||Epoch_G_Loss:0.8542
# timer:  0.4640 sec.
# -------------
# Epoch 297/500
# -------------
# （train）
# -------------
# epoch 297 || Epoch_D_Loss:0.0017 ||Epoch_G_Loss:0.8649
# timer:  0.4682 sec.
# -------------
# Epoch 298/500
# -------------
# （train）
# -------------
# epoch 298 || Epoch_D_Loss:0.0008 ||Epoch_G_Loss:0.9592
# timer:  0.4658 sec.
# -------------
# Epoch 299/500
# -------------
# （train）
# -------------
# epoch 299 || Epoch_D_Loss:0.0007 ||Epoch_G_Loss:1.0251
# timer:  0.4730 sec.
# -------------
# Epoch 300/500
# -------------
# （train）
# -------------
# epoch 300 || Epoch_D_Loss:0.0408 ||Epoch_G_Loss:0.7081
# timer:  0.4585 sec.
# -------------
# Epoch 301/500
# -------------
# （train）
# -------------
# epoch 301 || Epoch_D_Loss:0.0030 ||Epoch_G_Loss:0.7383
# timer:  0.4699 sec.
# -------------
# Epoch 302/500
# -------------
# （train）
# -------------
# epoch 302 || Epoch_D_Loss:0.0008 ||Epoch_G_Loss:0.9060
# timer:  0.4696 sec.
# -------------
# Epoch 303/500
# -------------
# （train）
# -------------
# epoch 303 || Epoch_D_Loss:0.0012 ||Epoch_G_Loss:1.1285
# timer:  0.4729 sec.
# -------------
# Epoch 304/500
# -------------
# （train）
# -------------
# epoch 304 || Epoch_D_Loss:0.0009 ||Epoch_G_Loss:0.9911
# timer:  0.4711 sec.
# -------------
# Epoch 305/500
# -------------
# （train）
# -------------
# epoch 305 || Epoch_D_Loss:0.0044 ||Epoch_G_Loss:1.2554
# timer:  0.4685 sec.
# -------------
# Epoch 306/500
# -------------
# （train）
# -------------
# epoch 306 || Epoch_D_Loss:0.0529 ||Epoch_G_Loss:0.6159
# timer:  0.4760 sec.
# -------------
# Epoch 307/500
# -------------
# （train）
# -------------
# epoch 307 || Epoch_D_Loss:0.0048 ||Epoch_G_Loss:0.7714
# timer:  0.4685 sec.
# -------------
# Epoch 308/500
# -------------
# （train）
# -------------
# epoch 308 || Epoch_D_Loss:0.0013 ||Epoch_G_Loss:0.8755
# timer:  0.4787 sec.
# -------------
# Epoch 309/500
# -------------
# （train）
# -------------
# epoch 309 || Epoch_D_Loss:0.0009 ||Epoch_G_Loss:0.9426
# timer:  0.4708 sec.
# -------------
# Epoch 310/500
# -------------
# （train）
# -------------
# epoch 310 || Epoch_D_Loss:0.0005 ||Epoch_G_Loss:1.0235
# timer:  0.4672 sec.
# -------------
# Epoch 311/500
# -------------
# （train）
# -------------
# epoch 311 || Epoch_D_Loss:0.0005 ||Epoch_G_Loss:1.1816
# timer:  0.4634 sec.
# -------------
# Epoch 312/500
# -------------
# （train）
# -------------
# epoch 312 || Epoch_D_Loss:0.0559 ||Epoch_G_Loss:0.7140
# timer:  0.4728 sec.
# -------------
# Epoch 313/500
# -------------
# （train）
# -------------
# epoch 313 || Epoch_D_Loss:0.0029 ||Epoch_G_Loss:0.7338
# timer:  0.4705 sec.
# -------------
# Epoch 314/500
# -------------
# （train）
# -------------
# epoch 314 || Epoch_D_Loss:0.0011 ||Epoch_G_Loss:0.8586
# timer:  0.4597 sec.
# -------------
# Epoch 315/500
# -------------
# （train）
# -------------
# epoch 315 || Epoch_D_Loss:0.0005 ||Epoch_G_Loss:0.9234
# timer:  0.4657 sec.
# -------------
# Epoch 316/500
# -------------
# （train）
# -------------
# epoch 316 || Epoch_D_Loss:0.0003 ||Epoch_G_Loss:1.0807
# timer:  0.4652 sec.
# -------------
# Epoch 317/500
# -------------
# （train）
# -------------
# epoch 317 || Epoch_D_Loss:0.0409 ||Epoch_G_Loss:0.9035
# timer:  0.4649 sec.
# -------------
# Epoch 318/500
# -------------
# （train）
# -------------
# epoch 318 || Epoch_D_Loss:0.0018 ||Epoch_G_Loss:0.8908
# timer:  0.4715 sec.
# -------------
# Epoch 319/500
# -------------
# （train）
# -------------
# epoch 319 || Epoch_D_Loss:0.0052 ||Epoch_G_Loss:0.9718
# timer:  0.4644 sec.
# -------------
# Epoch 320/500
# -------------
# （train）
# -------------
# epoch 320 || Epoch_D_Loss:0.0026 ||Epoch_G_Loss:0.9258
# timer:  0.4704 sec.
# -------------
# Epoch 321/500
# -------------
# （train）
# -------------
# epoch 321 || Epoch_D_Loss:0.0004 ||Epoch_G_Loss:1.0812
# timer:  0.4699 sec.
# -------------
# Epoch 322/500
# -------------
# （train）
# -------------
# epoch 322 || Epoch_D_Loss:0.0068 ||Epoch_G_Loss:1.0233
# timer:  0.4661 sec.
# -------------
# Epoch 323/500
# -------------
# （train）
# -------------
# epoch 323 || Epoch_D_Loss:0.0280 ||Epoch_G_Loss:0.6880
# timer:  0.4687 sec.
# -------------
# Epoch 324/500
# -------------
# （train）
# -------------
# epoch 324 || Epoch_D_Loss:0.0016 ||Epoch_G_Loss:0.7977
# timer:  0.4667 sec.
# -------------
# Epoch 325/500
# -------------
# （train）
# -------------
# epoch 325 || Epoch_D_Loss:0.0047 ||Epoch_G_Loss:0.8887
# timer:  0.4709 sec.
# -------------
# Epoch 326/500
# -------------
# （train）
# -------------
# epoch 326 || Epoch_D_Loss:0.0007 ||Epoch_G_Loss:1.0329
# timer:  0.4656 sec.
# -------------
# Epoch 327/500
# -------------
# （train）
# -------------
# epoch 327 || Epoch_D_Loss:0.0013 ||Epoch_G_Loss:1.0456
# timer:  0.4666 sec.
# -------------
# Epoch 328/500
# -------------
# （train）
# -------------
# epoch 328 || Epoch_D_Loss:0.0516 ||Epoch_G_Loss:0.6363
# timer:  0.4732 sec.
# -------------
# Epoch 329/500
# -------------
# （train）
# -------------
# epoch 329 || Epoch_D_Loss:0.0028 ||Epoch_G_Loss:0.7724
# timer:  0.4681 sec.
# -------------
# Epoch 330/500
# -------------
# （train）
# -------------
# epoch 330 || Epoch_D_Loss:0.0009 ||Epoch_G_Loss:0.9365
# timer:  0.4830 sec.
# -------------
# Epoch 331/500
# -------------
# （train）
# -------------
# epoch 331 || Epoch_D_Loss:0.0018 ||Epoch_G_Loss:0.9771
# timer:  0.4688 sec.
# -------------
# Epoch 332/500
# -------------
# （train）
# -------------
# epoch 332 || Epoch_D_Loss:0.0002 ||Epoch_G_Loss:1.0595
# timer:  0.4744 sec.
# -------------
# Epoch 333/500
# -------------
# （train）
# -------------
# epoch 333 || Epoch_D_Loss:0.0002 ||Epoch_G_Loss:1.1505
# timer:  0.4723 sec.
# -------------
# Epoch 334/500
# -------------
# （train）
# -------------
# epoch 334 || Epoch_D_Loss:0.0346 ||Epoch_G_Loss:0.8114
# timer:  0.4883 sec.
# -------------
# Epoch 335/500
# -------------
# （train）
# -------------
# epoch 335 || Epoch_D_Loss:0.0050 ||Epoch_G_Loss:0.7697
# timer:  0.4851 sec.
# -------------
# Epoch 336/500
# -------------
# （train）
# -------------
# epoch 336 || Epoch_D_Loss:0.0007 ||Epoch_G_Loss:0.9546
# timer:  0.4605 sec.
# -------------
# Epoch 337/500
# -------------
# （train）
# -------------
# epoch 337 || Epoch_D_Loss:0.0006 ||Epoch_G_Loss:1.0887
# timer:  0.4644 sec.
# -------------
# Epoch 338/500
# -------------
# （train）
# -------------
# epoch 338 || Epoch_D_Loss:0.0004 ||Epoch_G_Loss:1.1947
# timer:  0.4687 sec.
# -------------
# Epoch 339/500
# -------------
# （train）
# -------------
# epoch 339 || Epoch_D_Loss:0.0511 ||Epoch_G_Loss:0.6087
# timer:  0.4720 sec.
# -------------
# Epoch 340/500
# -------------
# （train）
# -------------
# epoch 340 || Epoch_D_Loss:0.0025 ||Epoch_G_Loss:0.7532
# timer:  0.4723 sec.
# -------------
# Epoch 341/500
# -------------
# （train）
# -------------
# epoch 341 || Epoch_D_Loss:0.0014 ||Epoch_G_Loss:0.9327
# timer:  0.4801 sec.
# -------------
# Epoch 342/500
# -------------
# （train）
# -------------
# epoch 342 || Epoch_D_Loss:0.0006 ||Epoch_G_Loss:1.0162
# timer:  0.4710 sec.
# -------------
# Epoch 343/500
# -------------
# （train）
# -------------
# epoch 343 || Epoch_D_Loss:0.0004 ||Epoch_G_Loss:1.1258
# timer:  0.4696 sec.
# -------------
# Epoch 344/500
# -------------
# （train）
# -------------
# epoch 344 || Epoch_D_Loss:0.0173 ||Epoch_G_Loss:1.0406
# timer:  0.4712 sec.
# -------------
# Epoch 345/500
# -------------
# （train）
# -------------
# epoch 345 || Epoch_D_Loss:0.0145 ||Epoch_G_Loss:0.6056
# timer:  0.4771 sec.
# -------------
# Epoch 346/500
# -------------
# （train）
# -------------
# ...
# -------------
# Epoch 385/500
# -------------
# （train）
# -------------
# epoch 385 || Epoch_D_Loss:0.0024 ||Epoch_G_Loss:1.0747
# timer:  0.4720 sec.
# -------------
# Epoch 386/500
# -------------
# （train）
# -------------
# epoch 386 || Epoch_D_Loss:0.0034 ||Epoch_G_Loss:1.0222
# timer:  0.4763 sec.
# -------------
# Epoch 387/500
# -------------
# （train）
# -------------
# epoch 387 || Epoch_D_Loss:0.0007 ||Epoch_G_Loss:1.0913
# timer:  0.4625 sec.
# -------------
# Epoch 388/500
# -------------
# （train）
# -------------
# epoch 388 || Epoch_D_Loss:0.0288 ||Epoch_G_Loss:0.9662
# timer:  0.4747 sec.
# -------------
# Epoch 389/500
# -------------
# （train）
# -------------
# epoch 389 || Epoch_D_Loss:0.0262 ||Epoch_G_Loss:0.6064
# timer:  0.4651 sec.
# -------------
# Epoch 390/500
# -------------
# （train）
# -------------
# epoch 390 || Epoch_D_Loss:0.0022 ||Epoch_G_Loss:0.8506
# timer:  0.4748 sec.
# -------------
# Epoch 391/500
# -------------
# （train）
# -------------
# epoch 391 || Epoch_D_Loss:0.0012 ||Epoch_G_Loss:1.0397
# timer:  0.4732 sec.
# -------------
# Epoch 392/500
# -------------
# （train）
# -------------
# epoch 392 || Epoch_D_Loss:0.0023 ||Epoch_G_Loss:1.0098
# timer:  0.4707 sec.
# -------------
# Epoch 393/500
# -------------
# （train）
# -------------
# epoch 393 || Epoch_D_Loss:0.0002 ||Epoch_G_Loss:1.1116
# timer:  0.4845 sec.
# -------------
# Epoch 394/500
# -------------
# （train）
# -------------
# epoch 394 || Epoch_D_Loss:0.0002 ||Epoch_G_Loss:1.2301
# timer:  0.4748 sec.
# -------------
# Epoch 395/500
# -------------
# （train）
# -------------
# epoch 395 || Epoch_D_Loss:0.0307 ||Epoch_G_Loss:1.0570
# timer:  0.4663 sec.
# -------------
# Epoch 396/500
# -------------
# （train）
# -------------
# epoch 396 || Epoch_D_Loss:0.0062 ||Epoch_G_Loss:0.7045
# timer:  0.4718 sec.
# -------------
# Epoch 397/500
# -------------
# （train）
# -------------
# epoch 397 || Epoch_D_Loss:0.0037 ||Epoch_G_Loss:0.8505
# timer:  0.4792 sec.
# -------------
# Epoch 398/500
# -------------
# （train）
# -------------
# epoch 398 || Epoch_D_Loss:0.0226 ||Epoch_G_Loss:0.8159
# timer:  0.4688 sec.
# -------------
# Epoch 399/500
# -------------
# （train）
# -------------
# epoch 399 || Epoch_D_Loss:0.0015 ||Epoch_G_Loss:1.0024
# timer:  0.4743 sec.
# -------------
# Epoch 400/500
# -------------
# （train）
# -------------
# epoch 400 || Epoch_D_Loss:0.0011 ||Epoch_G_Loss:1.1380
# timer:  0.4638 sec.
# -------------
# Epoch 401/500
# -------------
# （train）
# -------------
# epoch 401 || Epoch_D_Loss:0.0003 ||Epoch_G_Loss:1.1288
# timer:  0.4806 sec.
# -------------
# Epoch 402/500
# -------------
# （train）
# -------------
# epoch 402 || Epoch_D_Loss:0.0002 ||Epoch_G_Loss:1.2898
# timer:  0.4741 sec.
# -------------
# Epoch 403/500
# -------------
# （train）
# -------------
# epoch 403 || Epoch_D_Loss:0.0198 ||Epoch_G_Loss:1.1996
# timer:  0.4718 sec.
# -------------
# Epoch 404/500
# -------------
# （train）
# -------------
# epoch 404 || Epoch_D_Loss:0.0237 ||Epoch_G_Loss:0.5926
# timer:  0.4660 sec.
# -------------
# Epoch 405/500
# -------------
# （train）
# -------------
# epoch 405 || Epoch_D_Loss:0.0038 ||Epoch_G_Loss:0.7866
# timer:  0.4664 sec.
# -------------
# Epoch 406/500
# -------------
# （train）
# -------------
# epoch 406 || Epoch_D_Loss:0.0005 ||Epoch_G_Loss:1.1097
# timer:  0.4697 sec.
# -------------
# Epoch 407/500
# -------------
# （train）
# -------------
# epoch 407 || Epoch_D_Loss:0.0004 ||Epoch_G_Loss:1.0973
# timer:  0.4654 sec.
# -------------
# Epoch 408/500
# -------------
# （train）
# -------------
# epoch 408 || Epoch_D_Loss:0.0297 ||Epoch_G_Loss:1.0306
# timer:  0.4671 sec.
# -------------
# Epoch 409/500
# -------------
# （train）
# -------------
# epoch 409 || Epoch_D_Loss:0.0045 ||Epoch_G_Loss:0.8111
# timer:  0.4687 sec.
# -------------
# Epoch 410/500
# -------------
# （train）
# -------------
# epoch 410 || Epoch_D_Loss:0.0025 ||Epoch_G_Loss:0.9223
# timer:  0.4663 sec.
# -------------
# Epoch 411/500
# -------------
# （train）
# -------------
# epoch 411 || Epoch_D_Loss:0.0008 ||Epoch_G_Loss:1.0591
# timer:  0.4691 sec.
# -------------
# Epoch 412/500
# -------------
# （train）
# -------------
# epoch 412 || Epoch_D_Loss:0.0151 ||Epoch_G_Loss:0.9495
# timer:  0.4705 sec.
# -------------
# Epoch 413/500
# -------------
# （train）
# -------------
# epoch 413 || Epoch_D_Loss:0.0026 ||Epoch_G_Loss:1.0315
# timer:  0.4719 sec.
# -------------
# Epoch 414/500
# -------------
# （train）
# -------------
# epoch 414 || Epoch_D_Loss:0.0007 ||Epoch_G_Loss:1.1548
# timer:  0.4649 sec.
# -------------
# Epoch 415/500
# -------------
# （train）
# -------------
# epoch 415 || Epoch_D_Loss:0.0005 ||Epoch_G_Loss:1.2822
# timer:  0.4734 sec.
# -------------
# Epoch 416/500
# -------------
# （train）
# -------------
# epoch 416 || Epoch_D_Loss:0.0010 ||Epoch_G_Loss:1.1135
# timer:  0.4630 sec.
# -------------
# Epoch 417/500
# -------------
# （train）
# -------------
# epoch 417 || Epoch_D_Loss:0.0473 ||Epoch_G_Loss:1.1096
# timer:  0.4652 sec.
# -------------
# Epoch 418/500
# -------------
# （train）
# -------------
# epoch 418 || Epoch_D_Loss:0.0074 ||Epoch_G_Loss:0.6940
# timer:  0.4687 sec.
# -------------
# Epoch 419/500
# -------------
# （train）
# -------------
# epoch 419 || Epoch_D_Loss:0.0040 ||Epoch_G_Loss:0.8114
# timer:  0.4671 sec.
# -------------
# Epoch 420/500
# -------------
# （train）
# -------------
# epoch 420 || Epoch_D_Loss:0.0009 ||Epoch_G_Loss:0.9686
# timer:  0.4695 sec.
# -------------
# Epoch 421/500
# -------------
# （train）
# -------------
# epoch 421 || Epoch_D_Loss:0.0005 ||Epoch_G_Loss:1.0280
# timer:  0.4657 sec.
# -------------
# Epoch 422/500
# -------------
# （train）
# -------------
# epoch 422 || Epoch_D_Loss:0.0005 ||Epoch_G_Loss:1.1454
# timer:  0.4642 sec.
# -------------
# Epoch 423/500
# -------------
# （train）
# -------------
# epoch 423 || Epoch_D_Loss:0.0189 ||Epoch_G_Loss:1.1492
# timer:  0.4647 sec.
# -------------
# Epoch 424/500
# -------------
# （train）
# -------------
# epoch 424 || Epoch_D_Loss:0.0077 ||Epoch_G_Loss:0.7384
# timer:  0.4662 sec.
# -------------
# Epoch 425/500
# -------------
# （train）
# -------------
# epoch 425 || Epoch_D_Loss:0.0013 ||Epoch_G_Loss:0.9662
# timer:  0.4658 sec.
# -------------
# Epoch 426/500
# -------------
# （train）
# -------------
# epoch 426 || Epoch_D_Loss:0.0008 ||Epoch_G_Loss:1.1929
# timer:  0.4689 sec.
# -------------
# Epoch 427/500
# -------------
# （train）
# -------------
# epoch 427 || Epoch_D_Loss:0.0003 ||Epoch_G_Loss:1.2124
# timer:  0.4673 sec.
# -------------
# Epoch 428/500
# -------------
# （train）
# -------------
# epoch 428 || Epoch_D_Loss:0.0339 ||Epoch_G_Loss:1.2143
# timer:  0.4705 sec.
# -------------
# Epoch 429/500
# -------------
# （train）
# -------------
# epoch 429 || Epoch_D_Loss:0.0263 ||Epoch_G_Loss:0.6967
# timer:  0.4663 sec.
# -------------
# Epoch 430/500
# -------------
# （train）
# -------------
# epoch 430 || Epoch_D_Loss:0.0028 ||Epoch_G_Loss:0.7216
# timer:  0.4702 sec.
# -------------
# Epoch 431/500
# -------------
# （train）
# -------------
# epoch 431 || Epoch_D_Loss:0.0023 ||Epoch_G_Loss:0.8981
# timer:  0.4696 sec.
# -------------
# Epoch 432/500
# -------------
# （train）
# -------------
# epoch 432 || Epoch_D_Loss:0.0016 ||Epoch_G_Loss:0.9007
# timer:  0.4736 sec.
# -------------
# Epoch 433/500
# -------------
# （train）
# -------------
# epoch 433 || Epoch_D_Loss:0.0232 ||Epoch_G_Loss:1.0323
# timer:  0.4649 sec.
# -------------
# Epoch 434/500
# -------------
# （train）
# -------------
# epoch 434 || Epoch_D_Loss:0.0048 ||Epoch_G_Loss:0.9485
# timer:  0.4663 sec.
# -------------
# Epoch 435/500
# -------------
# （train）
# -------------
# epoch 435 || Epoch_D_Loss:0.0006 ||Epoch_G_Loss:1.0229
# timer:  0.4646 sec.
# -------------
# Epoch 436/500
# -------------
# （train）
# -------------
# epoch 436 || Epoch_D_Loss:0.0003 ||Epoch_G_Loss:1.1162
# timer:  0.4633 sec.
# -------------
# Epoch 437/500
# -------------
# （train）
# -------------
# epoch 437 || Epoch_D_Loss:0.0005 ||Epoch_G_Loss:1.2210
# timer:  0.4682 sec.
# -------------
# Epoch 438/500
# -------------
# （train）
# -------------
# epoch 438 || Epoch_D_Loss:0.0377 ||Epoch_G_Loss:1.0275
# timer:  0.4656 sec.
# -------------
# Epoch 439/500
# -------------
# （train）
# -------------
# epoch 439 || Epoch_D_Loss:0.0062 ||Epoch_G_Loss:0.8320
# timer:  0.4658 sec.
# -------------
# Epoch 440/500
# -------------
# （train）
# -------------
# epoch 440 || Epoch_D_Loss:0.0019 ||Epoch_G_Loss:0.9330
# timer:  0.4638 sec.
# -------------
# Epoch 441/500
# -------------
# （train）
# -------------
# epoch 441 || Epoch_D_Loss:0.0019 ||Epoch_G_Loss:1.0320
# timer:  0.4684 sec.
# -------------
# Epoch 442/500
# -------------
# （train）
# -------------
# epoch 442 || Epoch_D_Loss:0.0008 ||Epoch_G_Loss:1.1677
# timer:  0.4591 sec.
# -------------
# Epoch 443/500
# -------------
# （train）
# -------------
# epoch 443 || Epoch_D_Loss:0.0003 ||Epoch_G_Loss:1.1403
# timer:  0.4675 sec.
# -------------
# Epoch 444/500
# -------------
# （train）
# -------------
# epoch 444 || Epoch_D_Loss:0.0396 ||Epoch_G_Loss:1.1442
# timer:  0.4681 sec.
# -------------
# Epoch 445/500
# -------------
# （train）
# -------------
# epoch 445 || Epoch_D_Loss:0.0117 ||Epoch_G_Loss:0.6642
# timer:  0.4708 sec.
# -------------
# Epoch 446/500
# -------------
# （train）
# -------------
# epoch 446 || Epoch_D_Loss:0.0016 ||Epoch_G_Loss:0.9536
# timer:  0.4594 sec.
# -------------
# Epoch 447/500
# -------------
# （train）
# -------------
# epoch 447 || Epoch_D_Loss:0.0009 ||Epoch_G_Loss:1.0108
# timer:  0.4630 sec.
# -------------
# Epoch 448/500
# -------------
# （train）
# -------------
# epoch 448 || Epoch_D_Loss:0.0045 ||Epoch_G_Loss:1.0526
# timer:  0.4683 sec.
# -------------
# Epoch 449/500
# -------------
# （train）
# -------------
# epoch 449 || Epoch_D_Loss:0.0051 ||Epoch_G_Loss:0.8787
# timer:  0.4683 sec.
# -------------
# Epoch 450/500
# -------------
# （train）
# -------------
# epoch 450 || Epoch_D_Loss:0.0198 ||Epoch_G_Loss:0.9459
# timer:  0.4716 sec.
# -------------
# Epoch 451/500
# -------------
# （train）
# -------------
# epoch 451 || Epoch_D_Loss:0.0015 ||Epoch_G_Loss:1.0894
# timer:  0.4618 sec.
# -------------
# Epoch 452/500
# -------------
# （train）
# -------------
# epoch 452 || Epoch_D_Loss:0.0030 ||Epoch_G_Loss:1.0739
# timer:  0.4723 sec.
# -------------
# Epoch 453/500
# -------------
# （train）
# -------------
# epoch 453 || Epoch_D_Loss:0.0016 ||Epoch_G_Loss:1.0568
# timer:  0.4713 sec.
# -------------
# Epoch 454/500
# -------------
# （train）
# -------------
# epoch 454 || Epoch_D_Loss:0.0283 ||Epoch_G_Loss:0.7969
# timer:  0.4736 sec.
# -------------
# Epoch 455/500
# -------------
# （train）
# -------------
# epoch 455 || Epoch_D_Loss:0.0030 ||Epoch_G_Loss:0.9738
# timer:  0.4631 sec.
# -------------
# Epoch 456/500
# -------------
# （train）
# -------------
# epoch 456 || Epoch_D_Loss:0.0013 ||Epoch_G_Loss:1.1559
# timer:  0.4719 sec.
# -------------
# Epoch 457/500
# -------------
# （train）
# -------------
# epoch 457 || Epoch_D_Loss:0.0041 ||Epoch_G_Loss:1.1574
# timer:  0.4623 sec.
# -------------
# Epoch 458/500
# -------------
# （train）
# -------------
# epoch 458 || Epoch_D_Loss:0.0246 ||Epoch_G_Loss:0.7375
# timer:  0.4671 sec.
# -------------
# Epoch 459/500
# -------------
# （train）
# -------------
# epoch 459 || Epoch_D_Loss:0.0020 ||Epoch_G_Loss:0.8759
# timer:  0.4620 sec.
# -------------
# Epoch 460/500
# -------------
# （train）
# -------------
# epoch 460 || Epoch_D_Loss:0.0007 ||Epoch_G_Loss:1.0090
# timer:  0.4660 sec.
# -------------
# Epoch 461/500
# -------------
# （train）
# -------------
# epoch 461 || Epoch_D_Loss:0.0211 ||Epoch_G_Loss:1.0644
# timer:  0.4621 sec.
# -------------
# Epoch 462/500
# -------------
# （train）
# -------------
# epoch 462 || Epoch_D_Loss:0.0097 ||Epoch_G_Loss:0.7854
# timer:  0.4700 sec.
# -------------
# Epoch 463/500
# -------------
# （train）
# -------------
# epoch 463 || Epoch_D_Loss:0.0014 ||Epoch_G_Loss:1.0356
# timer:  0.4655 sec.
# -------------
# Epoch 464/500
# -------------
# （train）
# -------------
# epoch 464 || Epoch_D_Loss:0.0007 ||Epoch_G_Loss:1.0641
# timer:  0.4612 sec.
# -------------
# Epoch 465/500
# -------------
# （train）
# -------------
# epoch 465 || Epoch_D_Loss:0.0155 ||Epoch_G_Loss:1.1279
# timer:  0.4785 sec.
# -------------
# Epoch 466/500
# -------------
# （train）
# -------------
# epoch 466 || Epoch_D_Loss:0.0132 ||Epoch_G_Loss:0.8280
# timer:  0.4696 sec.
# -------------
# Epoch 467/500
# -------------
# （train）
# -------------
# epoch 467 || Epoch_D_Loss:0.0012 ||Epoch_G_Loss:0.8847
# timer:  0.4748 sec.
# -------------
# Epoch 468/500
# -------------
# （train）
# -------------
# epoch 468 || Epoch_D_Loss:0.0018 ||Epoch_G_Loss:0.9995
# timer:  0.4688 sec.
# -------------
# Epoch 469/500
# -------------
# （train）
# -------------
# epoch 469 || Epoch_D_Loss:0.0004 ||Epoch_G_Loss:1.0792
# timer:  0.4701 sec.
# -------------
# Epoch 470/500
# -------------
# （train）
# -------------
# epoch 470 || Epoch_D_Loss:0.0003 ||Epoch_G_Loss:1.1600
# timer:  0.4619 sec.
# -------------
# Epoch 471/500
# -------------
# （train）
# -------------
# epoch 471 || Epoch_D_Loss:0.0167 ||Epoch_G_Loss:1.0020
# timer:  0.4757 sec.
# -------------
# Epoch 472/500
# -------------
# （train）
# -------------
# epoch 472 || Epoch_D_Loss:0.0042 ||Epoch_G_Loss:1.0105
# timer:  0.4663 sec.
# -------------
# Epoch 473/500
# -------------
# （train）
# -------------
# epoch 473 || Epoch_D_Loss:0.0232 ||Epoch_G_Loss:0.7477
# timer:  0.4589 sec.
# -------------
# Epoch 474/500
# -------------
# （train）
# -------------
# epoch 474 || Epoch_D_Loss:0.0011 ||Epoch_G_Loss:0.8710
# timer:  0.4693 sec.
# -------------
# Epoch 475/500
# -------------
# （train）
# -------------
# epoch 475 || Epoch_D_Loss:0.0006 ||Epoch_G_Loss:1.1081
# timer:  0.4712 sec.
# -------------
# Epoch 476/500
# -------------
# （train）
# -------------
# epoch 476 || Epoch_D_Loss:0.0006 ||Epoch_G_Loss:1.1393
# timer:  0.4638 sec.
# -------------
# Epoch 477/500
# -------------
# （train）
# -------------
# epoch 477 || Epoch_D_Loss:0.0345 ||Epoch_G_Loss:1.0384
# timer:  0.4675 sec.
# -------------
# Epoch 478/500
# -------------
# （train）
# -------------
# epoch 478 || Epoch_D_Loss:0.0024 ||Epoch_G_Loss:0.7833
# timer:  0.4670 sec.
# -------------
# Epoch 479/500
# -------------
# （train）
# -------------
# epoch 479 || Epoch_D_Loss:0.0011 ||Epoch_G_Loss:0.9362
# timer:  0.4648 sec.
# -------------
# Epoch 480/500
# -------------
# （train）
# -------------
# epoch 480 || Epoch_D_Loss:0.0017 ||Epoch_G_Loss:1.0847
# timer:  0.4710 sec.
# -------------
# Epoch 481/500
# -------------
# （train）
# -------------
# epoch 481 || Epoch_D_Loss:0.0005 ||Epoch_G_Loss:1.0459
# timer:  0.4642 sec.
# -------------
# Epoch 482/500
# -------------
# （train）
# -------------
# epoch 482 || Epoch_D_Loss:0.0004 ||Epoch_G_Loss:1.2172
# timer:  0.4714 sec.
# -------------
# Epoch 483/500
# -------------
# （train）
# -------------
# epoch 483 || Epoch_D_Loss:0.0281 ||Epoch_G_Loss:1.0006
# timer:  0.4659 sec.
# -------------
# Epoch 484/500
# -------------
# （train）
# -------------
# epoch 484 || Epoch_D_Loss:0.0029 ||Epoch_G_Loss:0.8522
# timer:  0.4709 sec.
# -------------
# Epoch 485/500
# -------------
# （train）
# -------------
# epoch 485 || Epoch_D_Loss:0.0010 ||Epoch_G_Loss:1.0025
# timer:  0.4636 sec.
# -------------
# Epoch 486/500
# -------------
# （train）
# -------------
# epoch 486 || Epoch_D_Loss:0.0020 ||Epoch_G_Loss:1.1800
# timer:  0.4637 sec.
# -------------
# Epoch 487/500
# -------------
# （train）
# -------------
# epoch 487 || Epoch_D_Loss:0.0005 ||Epoch_G_Loss:1.2850
# timer:  0.4658 sec.
# -------------
# Epoch 488/500
# -------------
# （train）
# -------------
# epoch 488 || Epoch_D_Loss:0.0034 ||Epoch_G_Loss:1.2281
# timer:  0.4651 sec.
# -------------
# Epoch 489/500
# -------------
# （train）
# -------------
# epoch 489 || Epoch_D_Loss:0.0281 ||Epoch_G_Loss:0.9926
# timer:  0.4815 sec.
# -------------
# Epoch 490/500
# -------------
# （train）
# -------------
# epoch 490 || Epoch_D_Loss:0.0030 ||Epoch_G_Loss:0.8894
# timer:  0.4706 sec.
# -------------
# Epoch 491/500
# -------------
# （train）
# -------------
# epoch 491 || Epoch_D_Loss:0.0009 ||Epoch_G_Loss:1.0048
# timer:  0.4802 sec.
# -------------
# Epoch 492/500
# -------------
# （train）
# -------------
# epoch 492 || Epoch_D_Loss:0.0093 ||Epoch_G_Loss:1.0129
# timer:  0.4822 sec.
# -------------
# Epoch 493/500
# -------------
# （train）
# -------------
# epoch 493 || Epoch_D_Loss:0.0017 ||Epoch_G_Loss:0.9232
# timer:  0.4770 sec.
# -------------
# Epoch 494/500
# -------------
# （train）
# -------------
# epoch 494 || Epoch_D_Loss:0.0004 ||Epoch_G_Loss:1.1266
# timer:  0.4649 sec.
# -------------
# Epoch 495/500
# -------------
# （train）
# -------------
# epoch 495 || Epoch_D_Loss:0.0002 ||Epoch_G_Loss:1.1870
# timer:  0.4753 sec.
# -------------
# Epoch 496/500
# -------------
# （train）
# -------------
# epoch 496 || Epoch_D_Loss:0.0007 ||Epoch_G_Loss:1.2260
# timer:  0.4643 sec.
# -------------
# Epoch 497/500
# -------------
# （train）
# -------------
# epoch 497 || Epoch_D_Loss:0.0162 ||Epoch_G_Loss:1.0457
# timer:  0.4787 sec.
# -------------
# Epoch 498/500
# -------------
# （train）
# -------------
# epoch 498 || Epoch_D_Loss:0.0081 ||Epoch_G_Loss:0.8434
# timer:  0.4719 sec.
# -------------
# Epoch 499/500
# -------------
# （train）
# -------------
# epoch 499 || Epoch_D_Loss:0.0038 ||Epoch_G_Loss:1.1498
# timer:  0.4742 sec.

# %%
# 生成画像と訓練データを可視化する
# 本セルは良い感じの画像が生成されるまで、何度も実行し直しています。

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# 入力の乱数生成
batch_size = 8
z_dim = 20
fixed_z = torch.randn(batch_size, z_dim)
fixed_z = fixed_z.view(fixed_z.size(0), fixed_z.size(1), 1, 1)

# 画像生成
fake_images = G_update(fixed_z.to(device))

# 訓練データ
batch_iterator = iter(train_dataloader)  # イテレータに変換
images = next(batch_iterator)  # 1番目の要素を取り出す


# 出力
fig = plt.figure(figsize=(15, 6))
for i in range(0, 5):
    # 上段に訓練データを
    plt.subplot(2, 5, i+1)
    plt.imshow(imges[i][0].cpu().detach().numpy(), 'gray')

    # 下段に生成データを表示する
    plt.subplot(2, 5, 5+i+1)
    plt.imshow(fake_images[i][0].cpu().detach().numpy(), 'gray')

# %% [markdown]
# 以上
